# %% [markdown]
# # Web Scraping

# %% [markdown]
# ## Objetivo
#
# Nosso objetivo é encontrar algum site para ~~roubarmos~~ extrairmos informações e criarmos um banco de dados. *(com muito respeito)*

# %% [markdown]
# ![image.png](attachment:da871c29-5c43-41d8-a4fc-cb3901b5e135.png)

# %% [markdown]
# ## Encontra a Vítima Perfeita
#
# Nossa principal ferramenta nesse momento é o **"Ver Código Fonte"** do navegador.
#
# ### Sites Difíceis
# - **Javascript na página** ([UOL Política](https://noticias.uol.com.br/politica/))
# - **Páginas com "ver mais"** ([G1 Política](https://g1.globo.com/politica/))
#
# Para lidar com esses casos, precisamos usar uma ferramenta chamada **Selenium**.
#
# ### Sites Fáceis
# - **Páginas em HTML simples** ou com **URL editável** ([Senado Notícias](https://www12.senado.leg.br/noticias/temas/politica/pagina/1))
#
# **Encontramos nossa vítima!**

# %% [markdown]
# ## Arma do crime

# %% [markdown]
# #### **`requests`**
# - Biblioteca utilizada para **fazer requisições HTTP**.
# - Permite acessar páginas web e obter o conteúdo delas, como HTML, JSON ou arquivos de texto.
# - Fundamental para capturar o código-fonte de uma página para análise.
#
# #### **`BeautifulSoup`** (do pacote `bs4`)
# - Biblioteca usada para **analisar e manipular documentos HTML ou XML**.
# - Facilita a extração de informações específicas, como títulos, links ou tabelas, a partir do conteúdo HTML obtido.
#
# ### Fluxo básico:
# 1. Utilize `requests` para fazer a requisição e capturar o conteúdo HTML da página.
# 2. Use `BeautifulSoup` para analisar o HTML e extrair os dados que deseja.

# %% [markdown]
# ##  Capturando o HTML da Vítima

# %% [markdown]
# ![image.png](attachment:10d9c551-3a46-428f-a664-a3ae522b97ed.png)

# %%
import requests
from bs4 import BeautifulSoup

# %%
# URL da vítima
url = "https://www.agenciaminas.mg.gov.br/noticias?page=1&tema=esportes&territorio="

# Cabeçalho para simular um navegador
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url, headers=headers)
response
# <Response [200]> -> requisição foi bem-sucedida
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" xml:lang="pt-br" lang="pt-br" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" itemscope itemtype="http://schema.org/">\n<head>\n  <link rel="shortcut icon" type="image/x-icon" href="/assets/favicon-ff67004ef63143778f63114d3e89a222ac5ece29230ef719706855c99f8b02f4.ico" />\n  <link rel="stylesheet" media="all" href="/assets/application-cba39f7486a5bedb9e50b106fb2d54e0693a506c6ac4582bde60e61797f5da1b.css" data-turbolinks-track="true" />\n  <title>Agência Minas Gerais | Notícias</title>\n<meta name="description" content="Acompanhe todas as notícias oficiais do Governo de Minas Gerais relacionadas aos temas de interesse da população." />\n<meta name="keywords" content="agência minas gerais, governo estadual, estado, notícias, agropecuária, ciência e tecnologia, cultura, defesa social, desenvolvimento agrário, desenvolvimento econômico, direitos humanos, educação, esportes, fazenda, gestão, governo, infraestrutura, meio ambiente, saúde, social, trabalho e turismo" />\n<meta property="og:title" content="Governador" />\n<meta property="og:image" content="https://www.agenciaminas.mg.gov.br/assets/og_image_facebook-4a2265528f2938bda72e69b4263ef5d9e26de34206d721023dbf9b3ac87bb4f6.png" />\n<meta property="og:url" content="https://www.agenciaminas.mg.gov.br/noticias?page=1&amp;tema=esportes&amp;territorio=" />\n<meta property="og:description" content="Acompanhe todas as notícias oficiais do Governo de Minas Gerais relacionadas aos temas de interesse da população." />\n  <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">\n  <link href=\'http://fonts.googleapis.com/css?family=Lato:300,400,700&subset=latin\' rel=\'stylesheet\' type=\'text/css\'>\n  <meta name="robots" content="index, noarchive">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <!--[if lt IE 9]>\n        <script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script>\n<script src="https://cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script>\n        <body class="ltie9">\n        <link rel="stylesheet" media="screen" href="/assets/ltie9-e5a68ee0a80f7381ae88b7464be6635cec4ce3c71a84c7a1bcf662f8f50d1848.css" />\n    <![endif]-->\n\n  <script src="/assets/application-18b2367a57dd2b94b80a266e7fd534b6d5f6ea599ced82a41519dc4e98176382.js" data-turbolinks-track="true"></script>\n\n\n\n<!-- Em atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->\n<!-- Gilberto Moreira <gmsouza@gmail.com> -->\n<!-- ==================================================================================== -->\n<!-- Google Tag Manager -->\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-5D8P6T3J\');</script>\n<!-- End Google Tag Manager -->\n \n<!--\nStart of global snippet: Please do not remove\nPlace this snippet between the <head> and </head> tags on every page of your site.\n-->\n<!-- Google tag (gtag.js) -->\n<script async src="https://www.googletagmanager.com/gtag/js?id=DC-13051666"></script>\n<script>\nwindow.dataLayer = window.dataLayer || [];\nfunction gtag(){dataLayer.push(arguments);}\ngtag(\'js\', new Date());\ngtag(\'config\', \'DC-13051666\');\n</script>\n<!-- End of global snippet: Please do not remove -->\n\n<!-- ==================================================================================== -->\n<!-- Fim do atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->\n\n\n \n  \n\n<!-- Google tag (gtag.js) GA4-->\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-1N7SJXPM9Q"></script>\n<script>\n  window.dataLayer = window.dataLayer || [];\n ...

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" itemscope="" itemtype="http://schema.org/" lang="pt-br" xml:lang="pt-br" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# <link href="/assets/favicon-ff67004ef63143778f63114d3e89a222ac5ece29230ef719706855c99f8b02f4.ico" rel="shortcut icon" type="image/x-icon"/>
# <link data-turbolinks-track="true" href="/assets/application-cba39f7486a5bedb9e50b106fb2d54e0693a506c6ac4582bde60e61797f5da1b.css" media="all" rel="stylesheet"/>
# <title>Agência Minas Gerais | Notícias</title>
# <meta content="Acompanhe todas as notícias oficiais do Governo de Minas Gerais relacionadas aos temas de interesse da população." name="description"/>
# <meta content="agência minas gerais, governo estadual, estado, notícias, agropecuária, ciência e tecnologia, cultura, defesa social, desenvolvimento agrário, desenvolvimento econômico, direitos humanos, educação, esportes, fazenda, gestão, governo, infraestrutura, meio ambiente, saúde, social, trabalho e turismo" name="keywords"/>
# <meta content="Governador" property="og:title"/>
# <meta content="https://www.agenciaminas.mg.gov.br/assets/og_image_facebook-4a2265528f2938bda72e69b4263ef5d9e26de34206d721023dbf9b3ac87bb4f6.png" property="og:image"/>
# <meta content="https://www.agenciaminas.mg.gov.br/noticias?page=1&amp;tema=esportes&amp;territorio=" property="og:url"/>
# <meta content="Acompanhe todas as notícias oficiais do Governo de Minas Gerais relacionadas aos temas de interesse da população." property="og:description"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="http://fonts.googleapis.com/css?family=Lato:300,400,700&amp;subset=latin" rel="stylesheet" type="text/css"/>
# <meta content="index, noarchive" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!--[if lt IE 9]>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script>
#         <body class="ltie9">
#         <link rel="stylesheet" media="screen" href="/assets/ltie9-e5a68ee0a80f7381ae88b7464be6635cec4ce3c71a84c7a1bcf662f8f50d1848.css" />
#     <![endif]-->
# <script data-turbolinks-track="true" src="/assets/application-18b2367a57dd2b94b80a266e7fd534b6d5f6ea599ced82a41519dc4e98176382.js"></script>
# <!-- Em atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->
# <!-- Gilberto Moreira <gmsouza@gmail.com> -->
# <!-- ==================================================================================== -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5D8P6T3J');</script>
# <!-- End Google Tag Manager -->
# <!--
# Start of global snippet: Please do not remove
# Place this snippet between the <head> and </head> tags on every page of your site.
# -->
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-13051666"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'DC-13051666');
# </script>
# <!-- End of global snippet: Please do not remove -->
# <!-- ==================================================================================== -->
# <!-- Fim do atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->
# <!-- Google tag (gtag.js) GA4-->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-1N7SJXPM9Q"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-1N7SJXPM9Q');
#
# /*
# 	Versao anterior
#     function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     ga('create', 'UA-31022398-1', 'auto');
#     ga('send', 'pageview');
# */
#
#   </script>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="6nwRDXF3PAx7wxIhVG8DoNjP2YkzQxPYcrP5dfkv6GLlfuUGaYNfLXygBJ8nW1nRouH8OyqnlvLrIiLSp+RBgg==" name="csrf-token">
# </meta></meta></head>
# <body id="news-index">
# <!-- Em atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->
# <!-- Gilberto Moreira <gmsouza@gmail.com>============================================ -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5D8P6T3J" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Fim do atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->
# <header class="" id="header">
# <nav class="navbar navbar-default">
# <div class="navbar-header">
# <div class="navbar-header-content / container / padding-xs-y-2">
# <a href="/">
# <h1 class="logo">
# <span class="sr-only">Agência Minas Gerais</span>
# </h1>
# </a>
# <button aria-controls="navbar" class="navbar-toggle" type="button">
# <span class="sr-only">Abrir e fechar menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <div class="access / row / hidden-xs">
# <div class="margin-bottom-1 margin-top-1">
# <span>fonte</span>
# <a><i class="icon icon-text-less">A</i></a>
# <a><i class="icon icon-text-more">A</i></a>
# <i class="line-vertical line-vertical-5"></i>
# <span><a class="access-contrast" href="#">contraste</a></span>
# </div>
# <div class="search / hidden-xs / margin-md-left-2">
# <div class="box-search">
# <form action="/busca" method="get">
# <input id="term" name="term" placeholder="Busque por notícias, temas..." type="search"/>
# <input id="noticia" name="noticia" type="hidden" value="true"/>
# <input id="audio" name="audio" type="hidden" value="true"/>
# <input id="video" name="video" type="hidden" value="true"/>
# <input id="galeria" name="galeria" type="hidden" value="true"/>
# <button class="icon icon-busca text-hide" onclick="ga('send', 'event', 'Busca', 'Ir', 'Header');">buscar</button>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navbar-collapse">
# <div class="container">
# <div class="text-right / margin-top-1 margin-bottom-2 / visible-xs"><i class="icon icon-close"></i></div>
# <div class="margin-bottom-2 / center-block / visible-xs" style="width: 270px">
# <span>fonte</span>
# <a><i class="icon icon-text-less">A</i></a>
# <a><i class="icon icon-text-more">A</i></a>
# <span class="margin-left-2"><a class="access-contrast">contraste</a></span>
# </div>
# <a href="https://www.agenciaminas.mg.gov.br/">
# <h1 class="logo">
# <span class="sr-only">Agência Minas Gerais</span>
# </h1>
# </a>
# <ul class="nav navbar-nav">
# <!-- <li><a class="current-page" href="/noticias" title="noticias">notícias</a></li> -->
# <li><a class="current-page" href="javascript:void(0)">notícias</a>
# <ul class="submenu">
# <li><a href="/noticias">Últimas Notícias</a></li>
# <li><a class="current-page" href="http://www.2005-2015.agenciaminas.mg.gov.br/noticias/arquivo-geral" target="_blank">Arquivo: notícias de 2005-2015</a></li>
# <li><a class="current-page" href="http://www.2015-2018.agenciaminas.mg.gov.br/noticias" target="_blank">Arquivo: notícias de 2015-2018</a></li>
# </ul>
# </li>
# <li><a class="" href="javascript:void(0)">multimídia</a>
# <ul class="submenu">
# <li><a href="/multimidia/audios">Áudios</a></li>
# <li><a href="/multimidia/videos">Vídeos</a></li>
# <li><a href="/multimidia/galerias">Fotos</a></li>
# </ul>
# </li>
# <li><a class="" href="/eventos">programe-se</a></li>
# <li>
# <a class="" href="javascript:void(0)">governador</a>
# <ul class="submenu">
# <li><a href="/governador">Inicial</a></li>
# <li><a href="/governador#agenda">Agenda oficial</a></li>
# <li><a href="/multimidia/audios?governador=true">Áudios</a></li>
# <li><a href="/multimidia/videos?governador=true">Vídeos</a></li>
# <li><a href="/multimidia/galerias?governador=true">Fotos</a></li>
# </ul>
# </li>
# <li><a class="" href="/sala-de-imprensa">Sala de Imprensa</a></li>
# <li><a class="" href="/sites-do-governo">Sites do Governo</a></li>
# <li><a class="" href="https://www.mg.gov.br/" target="_blank">Serviços</a></li>
# <li><a class="" href="/contato">contato</a></li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <main id="content">
# <div class="container">
# <div class="search / padding-xs-y-3 / row / visible-xs">
# <div class="box-search">
# <form action="/busca" method="get">
# <input id="term" name="term" placeholder="Busque por notícias, temas..." type="search"/>
# <input id="noticia" name="noticia" type="hidden" value="true"/>
# <input id="audio" name="audio" type="hidden" value="true"/>
# <input id="video" name="video" type="hidden" value="true"/>
# <input id="galeria" name="galeria" type="hidden" value="true"/>
# </form>
# <button class="icon icon-busca text-hide">buscar</button>
# </div>
# </div>
# </div>
# <section class="news-list / margin-xs-top-1 margin-sm-top-2 / container">
# <header>
# <h1 class="text-title-3 color-1">Últimas Notícias</h1>
# <hr class="border-color-1 / margin-xs-bottom-1 margin-sm-bottom-2 / row"/>
# <!-- Filtro -->
# <div class="filter-icon text-right margin-bottom-1 visible-xs"><span>Acessar filtro de busca<i class="material-icons"></i></span></div>
# <div class="filter">
# <span class="label-title margin-xs-bottom-1 margin-sm-bottom-0 margin-xs-right-1 margin-sm-right-3">
# <strong>Filtrar por:</strong>
# </span>
# <form action="/noticias" method="get">
# <span class="group-checkbox">
# <span class="label-right">Governador</span>
# <input id="governador" name="governador" type="checkbox" value="true"/>
# <span class="label-left">Governador</span>
# <br class="visible-xs visible-sm"/>
# <!--<span class="label-right">Minas na mídia</span>-->
# <!--<input type="checkbox" name="clipping" id="clipping" value="true" />-->
# <!--<span class="label-left">Minas na mídia</span>-->
# </span>
# <span class="group-select">
# <label class="sr-only" for="filter-tema"> Escolha o tema</label>
# <select id="tema" name="tema"><option value="">Temas</option><option value="novo-acordo-de-mariana">Acordo do Rio Doce</option>
# <option value="agropecuaria">Agropecuária</option>
# <option value="bate-papo-com-o-governador">Bate-Papo com o Governador</option>
# <option value="brumadinho">Brumadinho</option>
# <option value="ciencia-e-tecnologia">Ciência e Tecnologia</option>
# <option value="coronavirus">Coronavírus</option>
# <option value="cultura">Cultura</option>
# <option value="defesa-civil">Defesa Civil</option>
# <option value="desenvolvimento-economico">Desenvolvimento Econômico</option>
# <option value="dia-da-mulher">Dia da Mulher </option>
# <option value="direitos-humanos">Direitos Humanos</option>
# <option value="educacao">Educação</option>
# <option value="ensino-superior">Ensino Superior</option>
# <option selected="selected" value="esportes">Esportes</option>
# <option value="fazenda">Fazenda</option>
# <option value="gestao">Gestão</option>
# <option value="governador">Governador</option>
# <option value="governo">Governo</option>
# <option value="infraestrutura">Infraestrutura</option>
# <option value="meio-ambiente">Meio Ambiente</option>
# <option value="minas-consciente">Minas Consciente</option>
# <option value="pesquisa">Pesquisa</option>
# <option value="previdencia">Previdência</option>
# <option value="publicidade">Publicidade</option>
# <option value="recupera-minas">Recupera Minas</option>
# <option value="reforma-da-previdencia">Reforma da Previdência</option>
# <option value="saude">Saúde</option>
# <option value="defesa-social">Segurança</option>
# <option value="servicos">Serviços</option>
# <option value="social">Social</option>
# <option value="trabalho">Trabalho</option>
# <option value="turismo">Turismo</option></select>
# <label class="sr-only" for="filter-territorios"> Escolha a região</label>
# <select id="territorio" name="territorio"><option value="">Regiões</option><option value="campo-das-vertentes">Campo das Vertentes</option>
# <option value="central">Central</option>
# <option value="oeste">Centro-Oeste</option>
# <option value="alto-jequitinhonha">Jequitinhonha</option>
# <option value="metropolitano">Metropolitana de Belo Horizonte</option>
# <option value="noroeste">Noroeste de Minas</option>
# <option value="norte">Norte de Minas</option>
# <option value="vale-do-rio-doce">Rio Doce</option>
# <option value="sul">Sul e Sudoeste</option>
# <option value="triangulo-norte">Triângulo Mineiro e Alto Paranaíba</option>
# <option value="vale-do-aco">Vale do Aço</option>
# <option value="mucuri">Vale do Mucuri</option>
# <option value="mata">Zona da Mata</option></select>
# </span>
# <button class="btn btn-primary" type="submit">Buscar</button>
# </form>
# </div>
# </header>
# <main id="blocknews">
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/656/thumb/NTF_3196.JPG?1775942454" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-educacao / margin-right-1" href="/noticias?tema=educacao">Educação</a>
# <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
# </div>
# <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Sáb 11 abril</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>18:20</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 18:20</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/627/thumb/NTF_1067_%281%29.jpg?1775759333" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
# </div>
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qui 09 abril</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>14:50</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 15:28</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas vistoria obras de revitalização de ginásio poliesportivo em Poços de Caldas </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas vistoria obras de revitalização de ginásio poliesportivo em Poços de Caldas </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/518/thumb/IMU_162.jpg?1774893874" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
# </div>
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Seg 30 março</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>15:10</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 17:55</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas vistoria instalações do programa Minas Urbano em Ipatinga </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas vistoria instalações do programa Minas Urbano em Ipatinga </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/168/thumb/WhatsApp_Image_2026-02-21_at_14.20.03.jpeg?1772042103" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-infraestrutura / margin-right-1" href="/noticias?tema=infraestrutura">Infraestrutura</a>
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-gestao / margin-right-1" href="/noticias?tema=gestao">Gestão</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-brumadinho / margin-right-1" href="/noticias?tema=brumadinho">Brumadinho</a>
# </div>
# <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qua 25 fevereiro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>15:00</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 15:10</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/021/thumb/25-_AP_2360.jpg?1770822921" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-defesa-social / margin-right-1" href="/noticias?tema=defesa-social">Segurança</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qua 11 fevereiro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>10:45</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 12:16</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo do Estado lança 3º Campeonato Mineiro de Futebol das Comunidades Terapêuticas </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo do Estado lança 3º Campeonato Mineiro de Futebol das Comunidades Terapêuticas </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/914/thumb/013f91c5-f30a-4c47-be9c-2a10844f98deeeeeee.jpg?1770057205" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Seg 02 fevereiro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>15:15</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 15:33</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas abre inscrições do Jemg 2026 para municípios mineiros </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas abre inscrições do Jemg 2026 para municípios mineiros </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/564/thumb/thumbnail_PEM-2025-medalha.png?1766169261" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Sex 19 dezembro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>09:00</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 16:23</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Prêmio do Esporte Mineiro reconhece talentos e celebra avanços históricos em 2025 </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Prêmio do Esporte Mineiro reconhece talentos e celebra avanços históricos em 2025 </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/541/thumb/PEM-2025-medalha.png?1766079025" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qui 18 dezembro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>14:30</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 14:40</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Prêmio do Esporte Mineiro chega à 9ª edição e celebra destaques esportivos em Minas Gerais </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Prêmio do Esporte Mineiro chega à 9ª edição e celebra destaques esportivos em Minas Gerais </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/522/thumb/WhatsApp_Image_2025-12-17_at_10.13.30.jpeg?1765977241" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-educacao / margin-right-1" href="/noticias?tema=educacao">Educação</a>
# </div>
# <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qua 17 dezembro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>10:20</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 10:31</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Estudantes de escola estadual de Caratinga conquistam medalhas nos Jogos Sul-Americanos Escolares 2025 </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Estudantes de escola estadual de Caratinga conquistam medalhas nos Jogos Sul-Americanos Escolares 2025 </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/391/thumb/PEM_2025-Arte_Divulga%C3%A7%C3%A3o.png?1764789265" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qua 03 dezembro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>17:30</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 17:31</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Pela primeira vez, Prêmio do Esporte Mineiro será transmitido na íntegra pela TV </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Pela primeira vez, Prêmio do Esporte Mineiro será transmitido na íntegra pela TV </h1>
# </a>
# </div>
# </section>
# <hr/>
# </main>
# <footer>
# <nav class="padding-y-3">
# <div class="pagination center-block"><span class="previous_page disabled"><span class="material-icons">  </span></span> <em class="current">1</em> <a href="/noticias?page=2&amp;tema=esportes&amp;territorio=" rel="next">2</a> <a href="/noticias?page=3&amp;tema=esportes&amp;territorio=">3</a> <span class="gap">...</span> <a href="/noticias?page=33&amp;tema=esportes&amp;territorio=">33</a> <a class="next_page" href="/noticias?page=2&amp;tema=esportes&amp;territorio=" rel="next"><span class="material-icons">  </span></a></div>
# </nav>
# </footer>
# </section>
# <!-- Página atualizada em 2026-04-14 11:12:28 -0300 -->
# </main>
# <footer class="margin-xs-top-3" id="footer">
# <div class="footer-1 / padding-sm-y-5 / hidden-xs hidden-sm">
# <div class="container">
# <div class="row">
# <section class="temas / col-md-3">
# <h1>Temas</h1>
# <ul class="no-bullets row">
# <li class="tema col-md-12 / menu">
# <a class="menu novo-acordo-de-mariana" href="javascript:void(0)">Acordo do Rio Doce</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=novo-acordo-de-mariana">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=novo-acordo-de-mariana">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=novo-acordo-de-mariana">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=novo-acordo-de-mariana">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu agropecuaria" href="javascript:void(0)">Agropecuária</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=agropecuaria">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=agropecuaria">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=agropecuaria">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=agropecuaria">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu bate-papo-com-o-governador" href="javascript:void(0)">Bate-Papo com o Governador</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=bate-papo-com-o-governador">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=bate-papo-com-o-governador">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=bate-papo-com-o-governador">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=bate-papo-com-o-governador">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu brumadinho" href="javascript:void(0)">Brumadinho</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=brumadinho">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=brumadinho">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=brumadinho">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=brumadinho">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu ciencia-e-tecnologia" href="javascript:void(0)">Ciência e Tecnologia</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=ciencia-e-tecnologia">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=ciencia-e-tecnologia">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=ciencia-e-tecnologia">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=ciencia-e-tecnologia">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu coronavirus" href="javascript:void(0)">Coronavírus</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=coronavirus">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=coronavirus">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=coronavirus">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=coronavirus">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu cultura" href="javascript:void(0)">Cultura</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=cultura">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=cultura">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=cultura">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=cultura">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu defesa-civil" href="javascript:void(0)">Defesa Civil</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=defesa-civil">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=defesa-civil">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=defesa-civil">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=defesa-civil">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu desenvolvimento-economico" href="javascript:void(0)">Desenvolvimento Econômico</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=desenvolvimento-economico">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=desenvolvimento-economico">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=desenvolvimento-economico">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=desenvolvimento-economico">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu dia-da-mulher" href="javascript:void(0)">Dia da Mulher </a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=dia-da-mulher">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=dia-da-mulher">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=dia-da-mulher">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=dia-da-mulher">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu direitos-humanos" href="javascript:void(0)">Direitos Humanos</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=direitos-humanos">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=direitos-humanos">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=direitos-humanos">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=direitos-humanos">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu educacao" href="javascript:void(0)">Educação</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=educacao">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=educacao">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=educacao">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=educacao">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu ensino-superior" href="javascript:void(0)">Ensino Superior</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=ensino-superior">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=ensino-superior">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=ensino-superior">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=ensino-superior">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu esportes" href="javascript:void(0)">Esportes</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=esportes">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=esportes">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=esportes">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=esportes">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu fazenda" href="javascript:void(0)">Fazenda</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=fazenda">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=fazenda">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=fazenda">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=fazenda">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu gestao" href="javascript:void(0)">Gestão</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=gestao">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=gestao">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=gestao">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=gestao">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu governador" href="javascript:void(0)">Governador</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=governador">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=governador">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=governador">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=governador">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu governo" href="javascript:void(0)">Governo</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=governo">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=governo">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=governo">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=governo">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu infraestrutura" href="javascript:void(0)">Infraestrutura</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=infraestrutura">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=infraestrutura">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=infraestrutura">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=infraestrutura">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu meio-ambiente" href="javascript:void(0)">Meio Ambiente</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=meio-ambiente">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=meio-ambiente">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=meio-ambiente">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=meio-ambiente">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu minas-consciente" href="javascript:void(0)">Minas Consciente</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=minas-consciente">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=minas-consciente">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=minas-consciente">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=minas-consciente">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu pesquisa" href="javascript:void(0)">Pesquisa</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=pesquisa">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=pesquisa">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=pesquisa">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=pesquisa">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu previdencia" href="javascript:void(0)">Previdência</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=previdencia">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=previdencia">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=previdencia">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=previdencia">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu publicidade" href="javascript:void(0)">Publicidade</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=publicidade">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=publicidade">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=publicidade">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=publicidade">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu recupera-minas" href="javascript:void(0)">Recupera Minas</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=recupera-minas">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=recupera-minas">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=recupera-minas">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=recupera-minas">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu reforma-da-previdencia" href="javascript:void(0)">Reforma da Previdência</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=reforma-da-previdencia">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=reforma-da-previdencia">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=reforma-da-previdencia">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=reforma-da-previdencia">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu saude" href="javascript:void(0)">Saúde</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=saude">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=saude">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=saude">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=saude">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu defesa-social" href="javascript:void(0)">Segurança</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=defesa-social">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=defesa-social">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=defesa-social">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=defesa-social">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu servicos" href="javascript:void(0)">Serviços</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=servicos">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=servicos">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=servicos">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=servicos">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu social" href="javascript:void(0)">Social</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=social">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=social">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=social">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=social">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu trabalho" href="javascript:void(0)">Trabalho</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=trabalho">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=trabalho">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=trabalho">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=trabalho">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu turismo" href="javascript:void(0)">Turismo</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=turismo">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=turismo">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=turismo">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=turismo">Vídeos</a></li>
# </ul>
# </li>
# </ul>
# </section>
# <section class="col-md-3">
# <h1>Governador</h1>
# <ul class="no-bullets">
# <li><a href="/governador">Inicial</a></li>
# <li><a href="/governador#agenda">Agenda oficial</a></li>
# <!--<li><a href="/governador/pronunciamentos">Pronunciamentos</a></li>-->
# <!--<li><a href="/governador/biografia">Biografia</a></li>-->
# <li><a href="/multimidia/audios?governador=true">Áudio</a></li>
# <li><a href="/multimidia/videos?governador=true">Vídeo</a></li>
# <li><a href="/multimidia/galerias?governador=true">Fotos</a></li>
# </ul>
# </section>
# <section class="col-md-3">
# <h1>Regiões</h1>
# <ul class="no-bullets row">
# <li class="col-md-12"><a href="/noticias?territorio=campo-das-vertentes">Campo das Vertentes</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=central">Central</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=oeste">Centro-Oeste</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=alto-jequitinhonha">Jequitinhonha</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=metropolitano">Metropolitana de Belo Horizonte</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=noroeste">Noroeste de Minas</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=norte">Norte de Minas</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=vale-do-rio-doce">Rio Doce</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=sul">Sul e Sudoeste</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=triangulo-norte">Triângulo Mineiro e Alto Paranaíba</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=vale-do-aco">Vale do Aço</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=mucuri">Vale do Mucuri</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=mata">Zona da Mata</a></li>
# </ul>
# </section>
# <section class="col-md-3">
# <ul class="no-bullets uppercase">
# <li><a class="text-title block margin-bottom-1" href="https://www.agenciaminas.mg.gov.br/multimidia/galerias">Multimídia</a></li>
#
# <a class="text-title block margin-bottom-1" href="https://www.agenciaminas.mg.gov.br/eventos">Programe-se</a>
#
# <a class="text-title block margin-bottom-1" href="/sala-de-imprensa">Sala de Imprensa</a>
#
# <a class="text-title block margin-bottom-1" href="/sites-do-governo">Sites do Governo</a>
#
# <a class="text-title block margin-bottom-1" href="https://www.mg.gov.br/" target="_blank">Serviços</a>
#
# <a class="text-title block margin-bottom-1" href="/contato">contato</a>
#
# </ul>
# </section>
# </div>
# </div>
# </div>
# <div class="footer-2 / padding-xs-y-2 padding-sm-y-5">
# <div class="container">
# <div class="row">
# <section class="social-network / margin-xs-bottom-2 margin-sm-bottom-4 / overflow-hidden">
# <div class="icon-networks">
# <div class="col-xs-12 col-sm-6">
# <!-- <i class="icon-governo text-hide">Governo de Minas Gerais</i> -->
# </div>
# <div class="social-icons / col-xs-12 col-sm-6">
# <a href="https://www.facebook.com/governomg" onclick="ga('send', 'event','Social','Facebook');" target="_blank" title="Facebook"><span class="text-hide">Facebook</span><i class="icon-facebook"> </i></a>
# <a href="https://twitter.com/governomg" onclick="ga('send', 'event','Social','Twitter');" target="_blank" title="Twitter"><span class="text-hide">Twitter</span><i class="icon-twitter"> </i></a>
# <a href="https://www.youtube.com/user/governodeminasgerais" onclick="ga('send', 'event','Social','Youtube');" target="_blank" title="Youtube"><span class="text-hide">Youtube</span><i class="icon-youtube"> </i></a>
# <a href="https://instagram.com/governomg/" onclick="ga('send', 'event','Social','Instagram');" target="_blank" title="Instagram"><span class="text-hide">Instagram</span><i class="icon-instagram"> </i></a>
# <a href="/feed" onclick="ga('send', 'event','Social','RSS');" target="_blank" title="Feed RSS"><span class="text-hide">Feed de notícias</span><i class="icon-feed2"> </i></a>
# </div>
# </div>
# </section>
# <hr class="margin-xs-bottom-3 margin-xs-top-3 / visible-xs"/>
# <section class="newsletter / col-sm-5 col-md-4 / margin-xs-bottom-2">
# <div id="form-newsletter-container">
# <p class="margin-bottom-2 text-title"><strong>Receba notícias por e-mail</strong></p>
# <!--<form id="form-newsletter" class="new_newsletter" action="/newsletter" accept-charset="UTF-8" data-remote="true" method="post"><input name="utf8" type="hidden" value="&#x2713;" /> -->
# <!--<input placeholder="Nome" required="required" type="text" name="newsletter[name]" id="newsletter_name" /> -->
# <!--<input placeholder="E-mail" required="required" type="email" name="newsletter[email]" id="newsletter_email" /> -->
# <!--<input type="submit" name="commit" value="Enviar" onclick="ga(&#39;send&#39;, &#39;event&#39;, &#39;Newsletter&#39;, &#39;Rodape&#39;);" class="margin-top-1 btn btn-secondary" id="btn-submit-newsletter" data-loading-text="Aguarde..." /> -->
# <a href="https://forms.gle/3pPi8oZuQvi4DrZS7" onclick="ga('send', 'event','Social','Cadastre-se');" target="_blank" title="CADASTRE-SE"><i class="btn btn-secondary"> CADASTRE-SE</i></a>
#  </div>
# <div class="success" id="success-message-newsletter" style="display:none;">
# <div class="success-msg">
# <i class="material-icons color-1 check"></i>
# <p>Aguarde. Em breve, retornaremos seu contato.</p>
# <br/>
# <br/>
# <p>Obrigado.</p>
# </div>
# </div>
# </section>
# <div class="col-sm-6 col-md-5 / col-sm-offset-1 col-md-offset-2">
# <hr class="margin-xs-bottom-3 margin-xs-top-3 / visible-xs / row"/>
# <section class="general-info / clear">
# <p><strong>SECOM – Secretaria de Estado de Comunicação Social</strong></p>
# <p><strong>Cidade Administrativa Presidente Tancredo Neves</strong></p>
# <p class="margin-top-2 margin-bottom-2">
# <small>
#         SECOM – Secretaria de Estado de Comunicação Social <br>
# 				Cidade Administrativa Presidente Tancredo Neves<br>
# 				Rodovia Papa João Paulo II, 3777<br>
# 				Prédio Tiradentes, 3º andar<br/>
# 				Bairro Serra Verde - Belo Horizonte (MG)<br/>
# 				CEP: 31630-903<br/>
# <a href="http://www.agenciaminas.mg.gov.br/contato"><small>Fale conosco</small></a>
# <!-- Contato: Fale conosco (http://www.agenciaminas.mg.gov.br/contato)<br /> -->
# </br></br></br></small>
# </p>
# <p><a href="/aspectos-legais"><small>Aspectos Legais e Responsabilidades</small></a></p>
# <p><a href="/politicas-de-privacidade"><small>Política de Privacidade</small></a></p>
# </section>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </body>
# </html>

# %%
# Exibe o html como texto
print(soup.get_text())
# Out:
# Agência Minas Gerais | Notícias
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agência Minas Gerais
#
#
#
# Abrir e fechar menu
#
#
#
#
#
#
# fonte
# A
# A
#
# contraste
#
#
#
#
#
#
#
#
#
# buscar
#
#
#
#
#
#
#
#
#
#
# fonte
# A
# A
# contraste
#
#
#
# Agência Minas Gerais
#
#
#
#
# notícias
#
# Últimas Notícias
# Arquivo: notícias de 2005-2015
# Arquivo: notícias de 2015-2018
#
#
# multimídia
#
# Áudios
# Vídeos
# Fotos
#
#
# programe-se
#
# governador
#
# Inicial
# Agenda oficial
# Áudios
# Vídeos
# Fotos
#
#
# Sala de Imprensa
# Sites do Governo
# Serviços
# contato
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# buscar
#
#
#
#
#
# Últimas Notícias
#
#
# Acessar filtro de busca
#
#
# Filtrar por:
#
#
#
# Governador
#
# Governador
#
#
#
#
#
#
#  Escolha o tema
# TemasAcordo do Rio Doce
# Agropecuária
# Bate-Papo com o Governador
# Brumadinho
# Ciência e Tecnologia
# Coronavírus
# Cultura
# Defesa Civil
# Desenvolvimento Econômico
# Dia da Mulher
# Direitos Humanos
# Educação
# Ensino Superior
# Esportes
# Fazenda
# Gestão
# Governador
# Governo
# Infraestrutura
# Meio Ambiente
# Minas Consciente
# Pesquisa
# Previdência
# Publicidade
# Recupera Minas
# Reforma da Previdência
# Saúde
# Segurança
# Serviços
# Social
# Trabalho
# Turismo
#  Escolha a região
# RegiõesCampo das Vertentes
# Central
# Centro-Oeste
# Jequitinhonha
# Metropolitana de Belo Horizonte
# Noroeste de Minas
# Norte de Minas
# Rio Doce
# Sul e Sudoeste
# Triângulo Mineiro e Alto Paranaíba
# Vale do Aço
# Vale do Mucuri
# Zona da Mata
#
# Buscar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Governo
# Esportes
# Educação
# Governador
#
#
#
# Sáb 11 abril
#
#
# 18:20
#
# atualizado em 18:20
#
#
#  Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar
#
#
#
#
#  Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Social
# Governo
# Esportes
# Governador
#
#
#
# Qui 09 abril
#
#
# 14:50
#
# atualizado em 15:28
#
#
#  Governo de Minas vistoria obras de revitalização de ginásio poliesportivo em Poços de Caldas
#
#
#
#
#  Governo de Minas vistoria obras de revitalização de ginásio poliesportivo em Poços de Caldas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Social
# Governo
# Esportes
# Governador
#
#
#
# Seg 30 março
#
#
# 15:10
#
# atualizado em 17:55
#
#
#  Governo de Minas vistoria instalações do programa Minas Urbano em Ipatinga
#
#
#
#
#  Governo de Minas vistoria instalações do programa Minas Urbano em Ipatinga
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Infraestrutura
# Governo
# Gestão
# Esportes
# Brumadinho
#
#
#
# Qua 25 fevereiro
#
#
# 15:00
#
# atualizado em 15:10
#
#
#  Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho
#
#
#
#
#  Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Social
# Governo
# Segurança
# Esportes
#
#
#
# Qua 11 fevereiro
#
#
# 10:45
#
# atualizado em 12:16
#
#
#  Governo do Estado lança 3º Campeonato Mineiro de Futebol das Comunidades Terapêuticas
#
#
#
#
#  Governo do Estado lança 3º Campeonato Mineiro de Futebol das Comunidades Terapêuticas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Social
# Esportes
#
#
#
# Seg 02 fevereiro
#
#
# 15:15
#
# atualizado em 15:33
#
#
#  Governo de Minas abre inscrições do Jemg 2026 para municípios mineiros
#
#
#
#
#  Governo de Minas abre inscrições do Jemg 2026 para municípios mineiros
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Social
# Esportes
#
#
#
# Sex 19 dezembro
#
#
# 09:00
#
# atualizado em 16:23
#
#
#  Prêmio do Esporte Mineiro reconhece talentos e celebra avanços históricos em 2025
#
#
#
#
#  Prêmio do Esporte Mineiro reconhece talentos e celebra avanços históricos em 2025
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Social
# Esportes
#
#
#
# Qui 18 dezembro
#
#
# 14:30
#
# atualizado em 14:40
#
#
#  Prêmio do Esporte Mineiro chega à 9ª edição e celebra destaques esportivos em Minas Gerais
#
#
#
#
#  Prêmio do Esporte Mineiro chega à 9ª edição e celebra destaques esportivos em Minas Gerais
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Esportes
# Educação
#
#
#
# Qua 17 dezembro
#
#
# 10:20
#
# atualizado em 10:31
#
#
#  Estudantes de escola estadual de Caratinga conquistam medalhas nos Jogos Sul-Americanos Escolares 2025
#
#
#
#
#  Estudantes de escola estadual de Caratinga conquistam medalhas nos Jogos Sul-Americanos Escolares 2025
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Social
# Esportes
#
#
#
# Qua 03 dezembro
#
#
# 17:30
#
# atualizado em 17:31
#
#
#  Pela primeira vez, Prêmio do Esporte Mineiro será transmitido na íntegra pela TV
#
#
#
#
#  Pela primeira vez, Prêmio do Esporte Mineiro será transmitido na íntegra pela TV
#
#
#
#
#
#
#
#    1 2 3 ... 33  
#
#
#
#
#
#
#
#
#
#
# Temas
#
#
# Acordo do Rio Doce
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Agropecuária
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Bate-Papo com o Governador
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Brumadinho
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Ciência e Tecnologia
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Coronavírus
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Cultura
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Defesa Civil
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Desenvolvimento Econômico
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Dia da Mulher
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Direitos Humanos
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Educação
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Ensino Superior
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Esportes
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Fazenda
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Gestão
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Governador
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Governo
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Infraestrutura
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Meio Ambiente
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Minas Consciente
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Pesquisa
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Previdência
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Publicidade
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Recupera Minas
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Reforma da Previdência
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Saúde
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Segurança
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Serviços
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Social
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Trabalho
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
# Turismo
#
# Notícias
# Fotos
# Áudios
# Vídeos
#
#
#
#
#
# Governador
#
# Inicial
# Agenda oficial
#
#
# Áudio
# Vídeo
# Fotos
#
#
#
# Regiões
#
# Campo das Vertentes
# Central
# Centro-Oeste
# Jequitinhonha
# Metropolitana de Belo Horizonte
# Noroeste de Minas
# Norte de Minas
# Rio Doce
# Sul e Sudoeste
# Triângulo Mineiro e Alto Paranaíba
# Vale do Aço
# Vale do Mucuri
# Zona da Mata
#
#
#
#
# Multimídia
#
# Programe-se
#
# Sala de Imprensa
#
# Sites do Governo
#
# Serviços
#
# contato
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Facebook
# Twitter
# Youtube
# Instagram
# Feed de notícias
#
#
#
#
#
#
# Receba notícias por e-mail
#
#
#
#
#  CADASTRE-SE
#
#
#
# 
# Aguarde. Em breve, retornaremos seu contato.
#
#
# Obrigado.
#
#
#
#
#
#
# SECOM – Secretaria de Estado de Comunicação Social
# Cidade Administrativa Presidente Tancredo Neves
#
#
#         SECOM – Secretaria de Estado de Comunicação Social
# 				Cidade Administrativa Presidente Tancredo Neves
# 				Rodovia Papa João Paulo II, 3777
# 				Prédio Tiradentes, 3º andar
# 				Bairro Serra Verde - Belo Horizonte (MG)
# 				CEP: 31630-903
# Fale conosco
#
#
#
# Aspectos Legais e Responsabilidades
# Política de Privacidade

# %% [markdown]
# ## Procurando uma brecha
#
# ![image.png](attachment:4711a469-f85a-407c-a78e-0b5153a55c56.png)
#
# As Notícias Seguem o Seguinte Padrão:
#
# ```html
# <div id="textoMateria">
#     <h3>Todas matérias</h3>
#     <ol class="list-unstyled lista-resultados">
#         <li>
#             <p>
#                 <span class="glyphicon glyphicon-list-alt"></span>
#                 <a href="/noticias/materias/2024/12/13/cdh-apoia-criacao-da-frente-mista-de-combate-a-violencia-politica-de-genero">
#                     CDH apoia criação da Frente Mista de Combate à Violência Política de Gênero
#                 </a>
#                 <small class="text-muted">
#                     13/12/2024 15h11
#                 </small>
#             </p>
#         </li>
#     </ol>
# </div>

# %% [markdown]
# 	<section class="row / padding-y-2">
# 		<a href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho" class="link-container">
# 			<div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# 				<div class="image-container unveil">
# 					<img class="img-responsive" data-src="/system/news/images/000/129/168/thumb/WhatsApp_Image_2026-02-21_at_14.20.03.jpeg?1772042103" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif" alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" />
# 				</div>
# 			</div>
# 		</a>
# 			<div class="col-xxs col-xs-7 col-md-9">
# 				<div class="margin-bottom-1 / hidden-xs">
# 					<a class="btn-tema bg-infraestrutura / margin-right-1" href="/noticias?tema=infraestrutura">Infraestrutura</a>
# 					<a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# 					<a class="btn-tema bg-gestao / margin-right-1" href="/noticias?tema=gestao">Gestão</a>
# 					<a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# 					<a class="btn-tema bg-brumadinho / margin-right-1" href="/noticias?tema=brumadinho">Brumadinho</a>
# 				</div>
# 				<a href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho" class="link-container">
# 					<time datetime="2015-07-08" pubdate="2015-07-08" class="text-date text-date-1 block margin-bottom-1">
# 						<span>Qua 25 fevereiro</span>
# 						<span class="hidden-xs">
# 							<span class="line-vertical line-vertical-2"></span>
# 							<span>15:00</span>
# 							<span class="line-vertical line-vertical-2" style='display:none;'></span>
# 							<span style='display:none;'>atualizado em 15:10</span>
# 						</span>
# 					</time>
# 					<h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho </h1>
# 				</a>
# 			</div>
# 			<div class="col-xxs col-xs-7  /  margin-sm-top-1 / visible-xs visible-sm ">
# 				<a href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho" class="link-container">
# 					<h1 class="text-title-2 margin-bottom-0 color-darken-9"> Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho </h1>
# 				</a>
# 			</div>
# 	</section>

# %%
# Localizando o bloco todas as matérias (blocknews)
bloco_noticias = soup.find("main", id="blocknews")
bloco_noticias
# Out:
# <main id="blocknews">
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/656/thumb/NTF_3196.JPG?1775942454" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-educacao / margin-right-1" href="/noticias?tema=educacao">Educação</a>
# <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
# </div>
# <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Sáb 11 abril</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>18:20</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 18:20</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/627/thumb/NTF_1067_%281%29.jpg?1775759333" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
# </div>
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qui 09 abril</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>14:50</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 15:28</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas vistoria obras de revitalização de ginásio poliesportivo em Poços de Caldas </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas vistoria obras de revitalização de ginásio poliesportivo em Poços de Caldas </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/518/thumb/IMU_162.jpg?1774893874" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
# </div>
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Seg 30 março</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>15:10</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 17:55</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas vistoria instalações do programa Minas Urbano em Ipatinga </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas vistoria instalações do programa Minas Urbano em Ipatinga </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/168/thumb/WhatsApp_Image_2026-02-21_at_14.20.03.jpeg?1772042103" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-infraestrutura / margin-right-1" href="/noticias?tema=infraestrutura">Infraestrutura</a>
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-gestao / margin-right-1" href="/noticias?tema=gestao">Gestão</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-brumadinho / margin-right-1" href="/noticias?tema=brumadinho">Brumadinho</a>
# </div>
# <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qua 25 fevereiro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>15:00</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 15:10</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/021/thumb/25-_AP_2360.jpg?1770822921" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-defesa-social / margin-right-1" href="/noticias?tema=defesa-social">Segurança</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qua 11 fevereiro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>10:45</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 12:16</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo do Estado lança 3º Campeonato Mineiro de Futebol das Comunidades Terapêuticas </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo do Estado lança 3º Campeonato Mineiro de Futebol das Comunidades Terapêuticas </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/914/thumb/013f91c5-f30a-4c47-be9c-2a10844f98deeeeeee.jpg?1770057205" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Seg 02 fevereiro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>15:15</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 15:33</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas abre inscrições do Jemg 2026 para municípios mineiros </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas abre inscrições do Jemg 2026 para municípios mineiros </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/564/thumb/thumbnail_PEM-2025-medalha.png?1766169261" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Sex 19 dezembro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>09:00</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 16:23</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Prêmio do Esporte Mineiro reconhece talentos e celebra avanços históricos em 2025 </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Prêmio do Esporte Mineiro reconhece talentos e celebra avanços históricos em 2025 </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/541/thumb/PEM-2025-medalha.png?1766079025" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qui 18 dezembro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>14:30</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 14:40</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Prêmio do Esporte Mineiro chega à 9ª edição e celebra destaques esportivos em Minas Gerais </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Prêmio do Esporte Mineiro chega à 9ª edição e celebra destaques esportivos em Minas Gerais </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/522/thumb/WhatsApp_Image_2025-12-17_at_10.13.30.jpeg?1765977241" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-educacao / margin-right-1" href="/noticias?tema=educacao">Educação</a>
# </div>
# <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qua 17 dezembro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>10:20</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 10:31</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Estudantes de escola estadual de Caratinga conquistam medalhas nos Jogos Sul-Americanos Escolares 2025 </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Estudantes de escola estadual de Caratinga conquistam medalhas nos Jogos Sul-Americanos Escolares 2025 </h1>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row / padding-y-2">
# <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
# <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
# <div class="image-container unveil">
# <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/391/thumb/PEM_2025-Arte_Divulga%C3%A7%C3%A3o.png?1764789265" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
# </div>
# </div>
# </a>
# <div class="col-xxs col-xs-7 col-md-9">
# <div class="margin-bottom-1 / hidden-xs">
# <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# </div>
# <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
# <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
# <span>Qua 03 dezembro</span>
# <span class="hidden-xs">
# <span class="line-vertical line-vertical-2"></span>
# <span>17:30</span>
# <span class="line-vertical line-vertical-2" style="display:none;"></span>
# <span style="display:none;">atualizado em 17:31</span>
# </span>
# </time>
# <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Pela primeira vez, Prêmio do Esporte Mineiro será transmitido na íntegra pela TV </h1>
# </a>
# </div>
# <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
# <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
# <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Pela primeira vez, Prêmio do Esporte Mineiro será transmitido na íntegra pela TV </h1>
# </a>
# </div>
# </section>
# <hr/>
# </main>

# %%
secoes = bloco_noticias.find_all("section", class_=lambda c: c and "padding-y-2" in c)
secoes
# Out:
# [<section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/656/thumb/NTF_3196.JPG?1775942454" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  <a class="btn-tema bg-educacao / margin-right-1" href="/noticias?tema=educacao">Educação</a>
#  <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
#  </div>
#  <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Sáb 11 abril</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>18:20</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 18:20</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/627/thumb/NTF_1067_%281%29.jpg?1775759333" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
#  <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
#  </div>
#  <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Qui 09 abril</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>14:50</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 15:28</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas vistoria obras de revitalização de ginásio poliesportivo em Poços de Caldas </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas vistoria obras de revitalização de ginásio poliesportivo em Poços de Caldas </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/518/thumb/IMU_162.jpg?1774893874" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
#  <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
#  </div>
#  <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Seg 30 março</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>15:10</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 17:55</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas vistoria instalações do programa Minas Urbano em Ipatinga </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas vistoria instalações do programa Minas Urbano em Ipatinga </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/168/thumb/WhatsApp_Image_2026-02-21_at_14.20.03.jpeg?1772042103" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-infraestrutura / margin-right-1" href="/noticias?tema=infraestrutura">Infraestrutura</a>
#  <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
#  <a class="btn-tema bg-gestao / margin-right-1" href="/noticias?tema=gestao">Gestão</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  <a class="btn-tema bg-brumadinho / margin-right-1" href="/noticias?tema=brumadinho">Brumadinho</a>
#  </div>
#  <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Qua 25 fevereiro</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>15:00</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 15:10</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Igarapé inaugura segundo centro esportivo com recursos do Acordo de Brumadinho </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/129/021/thumb/25-_AP_2360.jpg?1770822921" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
#  <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
#  <a class="btn-tema bg-defesa-social / margin-right-1" href="/noticias?tema=defesa-social">Segurança</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  </div>
#  <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Qua 11 fevereiro</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>10:45</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 12:16</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo do Estado lança 3º Campeonato Mineiro de Futebol das Comunidades Terapêuticas </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo do Estado lança 3º Campeonato Mineiro de Futebol das Comunidades Terapêuticas </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/914/thumb/013f91c5-f30a-4c47-be9c-2a10844f98deeeeeee.jpg?1770057205" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  </div>
#  <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Seg 02 fevereiro</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>15:15</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 15:33</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Governo de Minas abre inscrições do Jemg 2026 para municípios mineiros </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Governo de Minas abre inscrições do Jemg 2026 para municípios mineiros </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/564/thumb/thumbnail_PEM-2025-medalha.png?1766169261" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  </div>
#  <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Sex 19 dezembro</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>09:00</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 16:23</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Prêmio do Esporte Mineiro reconhece talentos e celebra avanços históricos em 2025 </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Prêmio do Esporte Mineiro reconhece talentos e celebra avanços históricos em 2025 </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/541/thumb/PEM-2025-medalha.png?1766079025" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  </div>
#  <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Qui 18 dezembro</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>14:30</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 14:40</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Prêmio do Esporte Mineiro chega à 9ª edição e celebra destaques esportivos em Minas Gerais </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Prêmio do Esporte Mineiro chega à 9ª edição e celebra destaques esportivos em Minas Gerais </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/522/thumb/WhatsApp_Image_2025-12-17_at_10.13.30.jpeg?1765977241" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  <a class="btn-tema bg-educacao / margin-right-1" href="/noticias?tema=educacao">Educação</a>
#  </div>
#  <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Qua 17 dezembro</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>10:20</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 10:31</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Estudantes de escola estadual de Caratinga conquistam medalhas nos Jogos Sul-Americanos Escolares 2025 </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Estudantes de escola estadual de Caratinga conquistam medalhas nos Jogos Sul-Americanos Escolares 2025 </h1>
#  </a>
#  </div>
#  </section>,
#  <section class="row / padding-y-2">
#  <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
#  <div class="col-auto col-xs-5 col-md-3 / margin-xs-bottom-1 margin-sm-bottom-0">
#  <div class="image-container unveil">
#  <img alt="Unveil 8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca" class="img-responsive" data-src="/system/news/images/000/128/391/thumb/PEM_2025-Arte_Divulga%C3%A7%C3%A3o.png?1764789265" src="/assets/unveil-8a21a6f614db065bb1ca2c21a5c803aede783f93e5277febbd47f37d9dbae4ca.gif"/>
#  </div>
#  </div>
#  </a>
#  <div class="col-xxs col-xs-7 col-md-9">
#  <div class="margin-bottom-1 / hidden-xs">
#  <a class="btn-tema bg-social / margin-right-1" href="/noticias?tema=social">Social</a>
#  <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
#  </div>
#  <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
#  <time class="text-date text-date-1 block margin-bottom-1" datetime="2015-07-08" pubdate="2015-07-08">
#  <span>Qua 03 dezembro</span>
#  <span class="hidden-xs">
#  <span class="line-vertical line-vertical-2"></span>
#  <span>17:30</span>
#  <span class="line-vertical line-vertical-2" style="display:none;"></span>
#  <span style="display:none;">atualizado em 17:31</span>
#  </span>
#  </time>
#  <h1 class="text-title-2 color-darken-9 / hidden-xs hidden-sm"> Pela primeira vez, Prêmio do Esporte Mineiro será transmitido na íntegra pela TV </h1>
#  </a>
#  </div>
#  <div class="col-xxs col-xs-7 / margin-sm-top-1 / visible-xs visible-sm">
#  <a class="link-container" href="/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv">
#  <h1 class="text-title-2 margin-bottom-0 color-darken-9"> Pela primeira vez, Prêmio do Esporte Mineiro será transmitido na íntegra pela TV </h1>
#  </a>
#  </div>
#  </section>]

# %%
print(f"{len(secoes)} notícias encontradas\n")
# Out:
# 10 notícias encontradas

# %% [markdown]
# **O elemento \<div\> é uma tag HTML que representa uma divisão ou contêiner genérico dentro de uma página web.**

# %%
# "/noticia/estudantes-da-rede-estadual-conquistam-o-1-lugar-no-campeonato-mundial-de-jiu-jitsu"

# %%
# extraindo apenas links de notícias (sem duplicatas e sem links de tema)
BASE = "https://www.agenciaminas.mg.gov.br"

links = list(dict.fromkeys(
    BASE + a['href'] for a in bloco_noticias.find_all('a', href=True)
    if a['href'].startswith('/noticia/')
))

# Exibindo os links extraídos
for link in links:
    print(link)
# Out:
# https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar
# https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-vistoria-obras-de-revitalizacao-de-ginasio-poliesportivo-em-pocos-de-caldas
# https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-vistoria-instalacoes-do-programa-minas-urbano-em-ipatinga
# https://www.agenciaminas.mg.gov.br/noticia/igarape-inaugura-segundo-centro-esportivo-com-recursos-do-acordo-de-brumadinho
# https://www.agenciaminas.mg.gov.br/noticia/governo-do-estado-lanca-3-campeonato-mineiro-de-futebol-das-comunidades-terapeuticas
# https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-abre-inscricoes-do-jemg-2026-para-municipios-mineiros
# https://www.agenciaminas.mg.gov.br/noticia/premio-do-esporte-mineiro-reconhece-talentos-e-celebra-avancos-historicos-em-2025
# https://www.agenciaminas.mg.gov.br/noticia/premio-do-esporte-mineiro-chega-a-9-edicao-e-celebra-destaques-esportivos-em-minas-gerais
# https://www.agenciaminas.mg.gov.br/noticia/estudantes-de-escola-estadual-de-caratinga-conquistam-medalhas-nos-jogos-sul-americanos-escolares-2025
# https://www.agenciaminas.mg.gov.br/noticia/pela-primeira-vez-premio-do-esporte-mineiro-sera-transmitido-na-integra-pela-tv

# %% [markdown]
# **O que significa `'a', href=True`?**
#
# - **`'a'`**: Refere-se à tag `<a>` em HTML, que é usada para criar links.
# - **`href=True`**: Filtra apenas as tags `<a>` que possuem o atributo `href` definido, ou seja, que realmente apontam para algum link.
#
# Essa combinação é utilizada para identificar e extrair apenas os links válidos dentro de uma página HTML.

# %% [markdown]
# ## Acessando os bens
#
# ![image.png](attachment:b1dcc6f4-eec6-487c-b2b7-15f94b7846c5.png)
#
#
# Conseguimos um pedaço do link para acessar as notícias, o link completo é algo da forma
# https://www12.senado.leg.br + {link encontrado no passo anterior}

# %% [markdown]
# Vamos acessar as notícias agora!

# %%
# primeira notícia
full_url = links[0]
response = requests.get(full_url, headers=headers)

print(full_url)
# Out:
# https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" itemscope="" itemtype="http://schema.org/" lang="pt-br" xml:lang="pt-br" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml">
# <head>
# <link href="/assets/favicon-ff67004ef63143778f63114d3e89a222ac5ece29230ef719706855c99f8b02f4.ico" rel="shortcut icon" type="image/x-icon"/>
# <link data-turbolinks-track="true" href="/assets/application-cba39f7486a5bedb9e50b106fb2d54e0693a506c6ac4582bde60e61797f5da1b.css" media="all" rel="stylesheet"/>
# <title>Agência Minas Gerais | Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar</title>
# <meta content="O governador Mateus Simões inaugurou, nessa sexta-feira (10/4), a quadra poliesportiva Rita Aparecida Carvalho Giaretta, na Escola Municipal..." name="description"/>
# <meta content="governo, de, minas, inaugura, quadra, poliesportiva, em, andradas, e, fortalece, infraestrutura, escolar" name="keywords"/>
# <meta content="Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar" property="og:title"/>
# <meta content="https://www.agenciaminas.mg.gov.br/system/news/images/000/129/656/original/NTF_3196.JPG?1775942454" property="og:image"/>
# <meta content="https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar" property="og:url"/>
# <meta content="O governador Mateus Simões inaugurou, nessa sexta-feira (10/4), a quadra poliesportiva Rita Aparecida Carvalho Giaretta, na Escola Municipal..." property="og:description"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="http://fonts.googleapis.com/css?family=Lato:300,400,700&amp;subset=latin" rel="stylesheet" type="text/css"/>
# <meta content="index, noarchive" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!--[if lt IE 9]>
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/respond.js/1.4.2/respond.min.js"></script>
#         <body class="ltie9">
#         <link rel="stylesheet" media="screen" href="/assets/ltie9-e5a68ee0a80f7381ae88b7464be6635cec4ce3c71a84c7a1bcf662f8f50d1848.css" />
#     <![endif]-->
# <script data-turbolinks-track="true" src="/assets/application-18b2367a57dd2b94b80a266e7fd534b6d5f6ea599ced82a41519dc4e98176382.js"></script>
# <!-- Em atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->
# <!-- Gilberto Moreira <gmsouza@gmail.com> -->
# <!-- ==================================================================================== -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5D8P6T3J');</script>
# <!-- End Google Tag Manager -->
# <!--
# Start of global snippet: Please do not remove
# Place this snippet between the <head> and </head> tags on every page of your site.
# -->
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=DC-13051666"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# function gtag(){dataLayer.push(arguments);}
# gtag('js', new Date());
# gtag('config', 'DC-13051666');
# </script>
# <!-- End of global snippet: Please do not remove -->
# <!-- ==================================================================================== -->
# <!-- Fim do atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->
# <!-- Google tag (gtag.js) GA4-->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-1N7SJXPM9Q"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-1N7SJXPM9Q');
#
# /*
# 	Versao anterior
#     function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     ga('create', 'UA-31022398-1', 'auto');
#     ga('send', 'pageview');
# */
#
#   </script>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="58t0hfQDbtpUiOemjjXxWuLJdJIgRJYLc8k6OBK4llndENdj2ZPIbyDbL2AK+p2Lgfc2Ec8g6D/RHwk7/WJIjA==" name="csrf-token">
# </meta></meta></head>
# <body id="news-show">
# <!-- Em atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->
# <!-- Gilberto Moreira <gmsouza@gmail.com>============================================ -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5D8P6T3J" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- Fim do atendimento ao chamado https://informaticasegov.freshdesk.com/a/tickets/21316 -->
# <header class="" id="header">
# <nav class="navbar navbar-default">
# <div class="navbar-header">
# <div class="navbar-header-content / container / padding-xs-y-2">
# <a href="/">
# <h1 class="logo">
# <span class="sr-only">Agência Minas Gerais</span>
# </h1>
# </a>
# <button aria-controls="navbar" class="navbar-toggle" type="button">
# <span class="sr-only">Abrir e fechar menu</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <div class="access / row / hidden-xs">
# <div class="margin-bottom-1 margin-top-1">
# <span>fonte</span>
# <a><i class="icon icon-text-less">A</i></a>
# <a><i class="icon icon-text-more">A</i></a>
# <i class="line-vertical line-vertical-5"></i>
# <span><a class="access-contrast" href="#">contraste</a></span>
# </div>
# <div class="search / hidden-xs / margin-md-left-2">
# <div class="box-search">
# <form action="/busca" method="get">
# <input id="term" name="term" placeholder="Busque por notícias, temas..." type="search"/>
# <input id="noticia" name="noticia" type="hidden" value="true"/>
# <input id="audio" name="audio" type="hidden" value="true"/>
# <input id="video" name="video" type="hidden" value="true"/>
# <input id="galeria" name="galeria" type="hidden" value="true"/>
# <button class="icon icon-busca text-hide" onclick="ga('send', 'event', 'Busca', 'Ir', 'Header');">buscar</button>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="navbar-collapse">
# <div class="container">
# <div class="text-right / margin-top-1 margin-bottom-2 / visible-xs"><i class="icon icon-close"></i></div>
# <div class="margin-bottom-2 / center-block / visible-xs" style="width: 270px">
# <span>fonte</span>
# <a><i class="icon icon-text-less">A</i></a>
# <a><i class="icon icon-text-more">A</i></a>
# <span class="margin-left-2"><a class="access-contrast">contraste</a></span>
# </div>
# <a href="https://www.agenciaminas.mg.gov.br/">
# <h1 class="logo">
# <span class="sr-only">Agência Minas Gerais</span>
# </h1>
# </a>
# <ul class="nav navbar-nav">
# <!-- <li><a class="current-page" href="/noticias" title="noticias">notícias</a></li> -->
# <li><a class="current-page" href="javascript:void(0)">notícias</a>
# <ul class="submenu">
# <li><a href="/noticias">Últimas Notícias</a></li>
# <li><a class="current-page" href="http://www.2005-2015.agenciaminas.mg.gov.br/noticias/arquivo-geral" target="_blank">Arquivo: notícias de 2005-2015</a></li>
# <li><a class="current-page" href="http://www.2015-2018.agenciaminas.mg.gov.br/noticias" target="_blank">Arquivo: notícias de 2015-2018</a></li>
# </ul>
# </li>
# <li><a class="" href="javascript:void(0)">multimídia</a>
# <ul class="submenu">
# <li><a href="/multimidia/audios">Áudios</a></li>
# <li><a href="/multimidia/videos">Vídeos</a></li>
# <li><a href="/multimidia/galerias">Fotos</a></li>
# </ul>
# </li>
# <li><a class="" href="/eventos">programe-se</a></li>
# <li>
# <a class="" href="javascript:void(0)">governador</a>
# <ul class="submenu">
# <li><a href="/governador">Inicial</a></li>
# <li><a href="/governador#agenda">Agenda oficial</a></li>
# <li><a href="/multimidia/audios?governador=true">Áudios</a></li>
# <li><a href="/multimidia/videos?governador=true">Vídeos</a></li>
# <li><a href="/multimidia/galerias?governador=true">Fotos</a></li>
# </ul>
# </li>
# <li><a class="" href="/sala-de-imprensa">Sala de Imprensa</a></li>
# <li><a class="" href="/sites-do-governo">Sites do Governo</a></li>
# <li><a class="" href="https://www.mg.gov.br/" target="_blank">Serviços</a></li>
# <li><a class="" href="/contato">contato</a></li>
# </ul>
# </div>
# </div>
# </nav>
# </header>
# <main id="content">
# <div class="container">
# <div class="search / padding-xs-y-3 / row / visible-xs">
# <div class="box-search">
# <form action="/busca" method="get">
# <input id="term" name="term" placeholder="Busque por notícias, temas..." type="search"/>
# <input id="noticia" name="noticia" type="hidden" value="true"/>
# <input id="audio" name="audio" type="hidden" value="true"/>
# <input id="video" name="video" type="hidden" value="true"/>
# <input id="galeria" name="galeria" type="hidden" value="true"/>
# </form>
# <button class="icon icon-busca text-hide">buscar</button>
# </div>
# </div>
# </div>
# <div class="container container-news margin-xs-top-2 margin-xs-bottom-2 margin-sm-top-4 margin-sm-bottom-2">
# <div class="news">
# <div class="margin-bottom-1 / col-md-10 col-md-offset-1 / hidden-xs">
# <div class="row">
# <div class="col-xs-12 col-lg-9">
# <a class="btn-tema bg-governo / margin-right-1" href="/noticias?tema=governo">Governo</a>
# <a class="btn-tema bg-esportes / margin-right-1" href="/noticias?tema=esportes">Esportes</a>
# <a class="btn-tema bg-educacao / margin-right-1" href="/noticias?tema=educacao">Educação</a>
# <a class="btn-tema bg-governador / margin-right-1" href="/noticias?tema=governador">Governador</a>
# </div>
# <div class="news-utils / col-lg-3 / pull-right text-right">
# <div class="row">
# <span class="text-warning">download</span>
# <a class="" href="/news/pdf/129656.pdf" onclick="ga('send', 'event','Download Notícia', 'Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar');" target="_blank"><i class="material-icons"></i></a>
# </div>
# </div>
# </div>
# </div>
# <article class="clear">
# <header class="col-md-10 col-md-offset-1 / margin-md-bottom-1">
# <time class="text-date text-date-1" datetime="2026-04-11 18:20:00 -0300" pubdate="">
# <span>Sáb 11 abril 2026</span>
# <span class="line-vertical line-vertical-2"></span>
# <span>18:20</span>
# <span class="line-vertical line-vertical-2"></span>
# <span>atualizado em Sáb 11 abril 2026 18:20</span>
# </time>
# <h1 class="text-title-4 / clear / margin-top-1">Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar</h1>
# <h2 class="text-subtitle">Novo espaço amplia oportunidades para prática esportiva e atividades pedagógicas na rede municipal</h2>
# </header>
# <main class="clear margin-md-bottom-3">
# <div class="news-image / margin-xs-bottom-1 margin-sm-bottom-2 margin-md-bottom-3">
# <div class="news-image-block relative">
# <img alt="imagem de destaque" class="" src="/system/news/images/000/129/656/large/NTF_3196.JPG?1775942454"/>
# <span class="credits credits-bottom credits-right hidden-xs">Karoline Barreto / Imprensa MG</span>
# </div>
# <div class="news-image-info">
# <div class="news-image-text / col-sm-12 col-md-9 / figcaption">
# </div>
# <div class="news-image-text file-download / col-md-3 / hidden-xs hidden-sm text-right">
# <a download="" href="/system/news/images/000/129/656/original/NTF_3196.JPG?1775942454" target="_blank">
# <span>download da imagem</span>
# <i class="material-icons"></i>
# </a>
# </div>
# </div>
# <div class="news-share margin-md-bottom-5 margin-top-1 / overflow-hidden">
# <ul class="no-bullets">
# <li class="text-hide">ícone de compartilhamento</li>
# <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar" target="_blank" title="Compartilhar no Facebook"></a></li>
# <li class="twitter"><a href="https://twitter.com/home?status=https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar" target="_blank" title="Compartilhar no Twitter"></a></li>
# <li class="google"><a href="https://plus.google.com/share?url=https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar" target="_blank" title="Compartilhar no Google Plus"></a></li>
# <li class="linkedin">
# <a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar&amp;title=Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar" target="blank" title="Compartilhar no LinkedIn"></a>
# </li>
# <li class="wtsp visible-xs"><a data-href="https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar" data-text="Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar" href="whatsapp://send?text=Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar | https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar" title="Compartilhar no Whatsapp"></a></li>
# <li class="mail"><a href="mailto:?subject=Agência Minas Gerais - Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar&amp;body=Veja esta notícia em https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar" title="Enviar por email"></a></li>
# </ul>
# </div>
# </div>
# <div class="clear">
# <section class="news-related / col-md-4 col-lg-3 / margin-md-bottom-2 margin-left-1 / pull-right / hidden-xs hidden-sm">
# <header>
# <p class="text-title-section / margin-bottom-1">Relacionadas</p>
# </header>
# <main>
# <div class="margin-md-bottom-2 row">
# <div class="col-xs-2 margin-top-2">
# <span class="icon-multimidia icon-sm"><i class="material-icons"></i></span>
# </div>
# <div class="col-xs-10">
# <span class="badge">Galeria</span>
# <a class="link-container" href="/multimidia/galeria/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
# <h1 class="text-subtitle inline">Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar</h1>
# </a>
# </div>
# </div>
# <hr class="row margin-md-bottom-2"/>
# <div class="margin-md-bottom-2 row">
# <div class="col-xs-2 margin-top-2">
# <span class="icon-multimidia icon-sm"><i class="material-icons"></i></span>
# </div>
# <div class="col-xs-10">
# <span class="badge">Notícia</span>
# <a class="link-container" href="/noticia/governo-de-minas-transfere-capital-para-pocos-de-caldas-anuncia-novo-colegio-tiradentes-e-r-7-5-milhoes-para-armamento-da-policia-civil">
# <h1 class="text-subtitle inline">Governo de Minas transfere capital para Poços de Caldas, anuncia novo Colégio Tiradentes e R$ 7,5 milhões para armamento da Polícia Civil</h1>
# </a>
# </div>
# </div>
# <hr class="row margin-md-bottom-2"/>
# </main>
# </section>
# <p><p>O governador Mateus Simões inaugurou, nessa sexta-feira (10/4), a quadra poliesportiva Rita Aparecida Carvalho Giaretta, na Escola Municipal Floriza Maniassi Trevisan, em Andradas, no Sul de Minas.<br/>
# <br/>
# A nova estrutura foi viabilizada por meio do Programa de Fortalecimento das Escolas Municipais, da <a href="https://desenvolvimento.mg.gov.br/" target="_blank">Secretaria de Estado de Educação de Minas Gerais (SEE/MG)</a>, e representa um importante avanço para a unidade, oferecendo um espaço adequado para a prática de esportes, atividades pedagógicas e integração entre os estudantes. <br/>
# <br/>
# “Com a entrega de uma das quadras no nosso programa com mais uma escola parceira, neste programa de fortalecimento das escolas municipais com verbas estaduais, percebemos como isso vai mudar a vida das crianças que estão aqui”, disse o governador Mateus Simões. <br/>
# <br/>
# A construção da quadra foi realizada por meio de um convênio, com R$ 572,8 mil de recursos do <a href="https://www.mg.gov.br/" target="_blank">Governo de Minas</a> e contrapartida de R$ 94 mil da Prefeitura de Andradas.<br/>
# <br/>
# Localizada no bairro do Horto, a Escola Municipal Floriza Maniassi Trevisan atende estudantes dos anos iniciais do ensino fundamental, de manhã e à tarde. A nova estrutura contempla uma demanda antiga da comunidade, que há anos convivia com uma quadra em condições precárias, sem condições de uso.<br/>
# <br/>
# O novo espaço foi planejado para oferecer mais segurança, qualidade e ampliar o acesso às atividades esportivas e de convivência. <br/>
# <br/>
# Ao inaugurar a obra, Simões aproveitou para ressaltar outro projeto educacional, com a ampliação da rede de Colégios Tiradentes, da <a href="https://www.policiamilitar.mg.gov.br/" target="_blank">Polícia Militar de Minas Gerais (PMMG)</a>, que vem sendo realizado no estado, e que terá uma nova unidade na região.<br/>
# <br/>
# “Logo aqui do lado, em Poços de Caldas, nós vamos inaugurar um Colégio Tiradentes, a partir do ano que vem, uma escola que se converte ao modelo militar, mais uma dentre as 30 que nós estamos anunciando no estado”, destacou o governador de Minas Gerais.<br/>
# <br/>
# <strong>Programa de fortalecimento </strong><br/>
# <br/>
# O município de Andradas recebeu R$ 1,3 milhão em investimentos por meio do Programa de Fortalecimento das Escolas Municipais, sendo R$ 572,8 mil para a construção da quadra, R$ 100 mil para aquisição de mobiliários e equipamentos escolares, e R$ 675,6 mil para aquisição de um veículo de transporte escolar. <br/>
# <br/>
# Idealizado pela <a href="https://www.governo.mg.gov.br/" target="_blank">Secretaria de Estado de Governo (Segov-MG)</a> e pela SEE/MG, o programa tem como objetivo principal promover a qualidade da educação básica e reduzir as desigualdades educacionais em Minas Gerais.<br/>
# <br/>
# A iniciativa destina recursos de acordo com as necessidades de cada município, por meio de convênios firmados com as prefeituras. Os investimentos contemplam a aquisição de veículos escolares, mobiliário e equipamentos, além da construção, reforma e ampliação de escolas e quadras poliesportivas.<br/>
# <br/>
# Desde 2021, o programa já firmou mais de 2 mil convênios com 820 municípios mineiros, totalizando um investimento de R$ 1,7 bilhão.<br/>
# <br/>
# Entre os destaques, estão mais de 850 convênios para aquisição de veículos escolares, somando R$ 1 bilhão, mais de 860 convênios para mobiliário e equipamentos permanentes, no valor de R$ 287 milhões, e mais de 360 convênios destinados à construção e reforma de escolas municipais, totalizando R$ 377 milhões.<br/>
# <br/>
# A inauguração da quadra poliesportiva em Andradas reforça o compromisso do Governo de Minas com a educação pública, por meio de investimentos contínuos que impactam diretamente o cotidiano das escolas e contribuem para ambientes mais adequados ao ensino e à aprendizagem.</p>
# <p> </p>
# </p>
# </div>
# </main>
# <br class="margin-bottom-2"/>
# <footer class="col-md-10 col-md-offset-1">
# <a class="text-call / margin-0" href="https://www.agenciaminas.mg.gov.br/noticias">outras notícias<i class="margin-left-1 icon icon-more"></i></a>
# </footer>
# </article>
# <section class="news-related / col-xs-12 / visible-xs visible-sm">
# <header>
# <p class="text-title-section / margin-bottom-1">Relacionadas</p>
# </header>
# <main>
# <div class="margin-xs-bottom-1">
# <span class="badge">Galeria</span>
# <a class="link-container" href="/multimidia/galeria/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar">
# <h1 class="text-subtitle inline">Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar</h1>
# </a>
# </div>
# <hr class="row margin-xs-bottom-1"/>
# <div class="margin-xs-bottom-1">
# <span class="badge">Notícia</span>
# <a class="link-container" href="/noticia/governo-de-minas-transfere-capital-para-pocos-de-caldas-anuncia-novo-colegio-tiradentes-e-r-7-5-milhoes-para-armamento-da-policia-civil">
# <h1 class="text-subtitle inline">Governo de Minas transfere capital para Poços de Caldas, anuncia novo Colégio Tiradentes e R$ 7,5 milhões para armamento da Polícia Civil</h1>
# </a>
# </div>
# <hr class="row margin-xs-bottom-1"/>
# </main>
# </section>
# </div>
# </div>
# <div class="container">
# <hr class="row margin-xs-bottom-2 margin-md-bottom-4"/>
# <section>
# <header>
# <h1 class="text-title-3 color-1">Últimas</h1>
# <hr class="border-color-1 / margin-xs-bottom-1 margin-sm-bottom-2 / row clear"/>
# </header>
# <main class="row">
# <div class="col-xs-12 col-sm-6 col-md-3 margin-xs-bottom-1">
# <a class="link-container" href="/noticia/diamantina-e-a-6-cidade-a-receber-a-praca-de-servicos-governo-presente-com-atendimentos-gratuitos-a-populacao-veja-datas">
# <div class="news-last-description">
# <h1 class="text-title color-darken-9">Diamantina é a 6ª cidade a receber a Praça de Serviços - Governo Presente com atendimentos gratuitos à população; veja datas</h1>
# <span class="block / text-date text-date-1 / margin-bottom-1">Ter 14 abril</span>
# <h2 class="text-subtitle color-darken-9">Projeto reúne emissão de documentos, serviços de saúde, apoio ao produtor...</h2>
# </div>
# <span class="text-call / margin-0">ler mais<i class="margin-left-1 icon icon-more"></i></span>
# </a>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 margin-xs-bottom-1">
# <a class="link-container" href="/noticia/governo-de-minas-vistoria-obras-da-nova-sede-do-corpo-de-bombeiros-em-diamantina">
# <div class="news-last-description">
# <h1 class="text-title color-darken-9">Governo de Minas vistoria obras da nova sede do Corpo de Bombeiros em Diamantina</h1>
# <span class="block / text-date text-date-1 / margin-bottom-1">Seg 13 abril</span>
# <h2 class="text-subtitle color-darken-9">Com investimento de R$ 8,1 milhões, projeto contempla importantes estruturas...</h2>
# </div>
# <span class="text-call / margin-0">ler mais<i class="margin-left-1 icon icon-more"></i></span>
# </a>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 margin-xs-bottom-1">
# <a class="link-container" href="/noticia/emti-impulsiona-protagonismo-estudantil-em-projeto-de-combate-a-dengue-em-patrocinio">
# <div class="news-last-description">
# <h1 class="text-title color-darken-9">EMTI impulsiona protagonismo estudantil em projeto de combate à dengue em Patrocínio</h1>
# <span class="block / text-date text-date-1 / margin-bottom-1">Seg 13 abril</span>
# <h2 class="text-subtitle color-darken-9"> Iniciativa “Minas Unidas contra o Aedes” mobiliza comunidade escolar e...</h2>
# </div>
# <span class="text-call / margin-0">ler mais<i class="margin-left-1 icon icon-more"></i></span>
# </a>
# </div>
# <div class="col-xs-12 col-sm-6 col-md-3 margin-xs-bottom-1">
# <a class="link-container" href="/noticia/estudantes-mineiros-ja-podem-solicitar-isencao-da-taxa-de-inscricao-do-enem-2026">
# <div class="news-last-description">
# <h1 class="text-title color-darken-9">Estudantes mineiros já podem solicitar isenção da taxa de inscrição do Enem 2026</h1>
# <span class="block / text-date text-date-1 / margin-bottom-1">Seg 13 abril</span>
# <h2 class="text-subtitle color-darken-9">Estudantes da rede pública de Minas Gerais devem fazer o pedido pela Página...</h2>
# </div>
# <span class="text-call / margin-0">ler mais<i class="margin-left-1 icon icon-more"></i></span>
# </a>
# </div>
# </main>
# </section>
# </div>
# <!-- Página atualizada em 2026-04-14 11:12:41 -0300 -->
# </main>
# <footer class="margin-xs-top-3" id="footer">
# <div class="footer-1 / padding-sm-y-5 / hidden-xs hidden-sm">
# <div class="container">
# <div class="row">
# <section class="temas / col-md-3">
# <h1>Temas</h1>
# <ul class="no-bullets row">
# <li class="tema col-md-12 / menu">
# <a class="menu novo-acordo-de-mariana" href="javascript:void(0)">Acordo do Rio Doce</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=novo-acordo-de-mariana">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=novo-acordo-de-mariana">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=novo-acordo-de-mariana">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=novo-acordo-de-mariana">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu agropecuaria" href="javascript:void(0)">Agropecuária</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=agropecuaria">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=agropecuaria">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=agropecuaria">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=agropecuaria">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu bate-papo-com-o-governador" href="javascript:void(0)">Bate-Papo com o Governador</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=bate-papo-com-o-governador">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=bate-papo-com-o-governador">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=bate-papo-com-o-governador">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=bate-papo-com-o-governador">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu brumadinho" href="javascript:void(0)">Brumadinho</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=brumadinho">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=brumadinho">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=brumadinho">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=brumadinho">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu ciencia-e-tecnologia" href="javascript:void(0)">Ciência e Tecnologia</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=ciencia-e-tecnologia">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=ciencia-e-tecnologia">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=ciencia-e-tecnologia">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=ciencia-e-tecnologia">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu coronavirus" href="javascript:void(0)">Coronavírus</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=coronavirus">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=coronavirus">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=coronavirus">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=coronavirus">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu cultura" href="javascript:void(0)">Cultura</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=cultura">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=cultura">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=cultura">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=cultura">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu defesa-civil" href="javascript:void(0)">Defesa Civil</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=defesa-civil">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=defesa-civil">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=defesa-civil">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=defesa-civil">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu desenvolvimento-economico" href="javascript:void(0)">Desenvolvimento Econômico</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=desenvolvimento-economico">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=desenvolvimento-economico">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=desenvolvimento-economico">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=desenvolvimento-economico">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu dia-da-mulher" href="javascript:void(0)">Dia da Mulher </a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=dia-da-mulher">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=dia-da-mulher">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=dia-da-mulher">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=dia-da-mulher">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu direitos-humanos" href="javascript:void(0)">Direitos Humanos</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=direitos-humanos">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=direitos-humanos">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=direitos-humanos">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=direitos-humanos">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu educacao" href="javascript:void(0)">Educação</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=educacao">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=educacao">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=educacao">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=educacao">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu ensino-superior" href="javascript:void(0)">Ensino Superior</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=ensino-superior">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=ensino-superior">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=ensino-superior">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=ensino-superior">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu esportes" href="javascript:void(0)">Esportes</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=esportes">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=esportes">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=esportes">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=esportes">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu fazenda" href="javascript:void(0)">Fazenda</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=fazenda">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=fazenda">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=fazenda">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=fazenda">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu gestao" href="javascript:void(0)">Gestão</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=gestao">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=gestao">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=gestao">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=gestao">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu governador" href="javascript:void(0)">Governador</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=governador">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=governador">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=governador">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=governador">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu governo" href="javascript:void(0)">Governo</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=governo">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=governo">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=governo">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=governo">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu infraestrutura" href="javascript:void(0)">Infraestrutura</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=infraestrutura">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=infraestrutura">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=infraestrutura">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=infraestrutura">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu meio-ambiente" href="javascript:void(0)">Meio Ambiente</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=meio-ambiente">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=meio-ambiente">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=meio-ambiente">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=meio-ambiente">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu minas-consciente" href="javascript:void(0)">Minas Consciente</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=minas-consciente">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=minas-consciente">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=minas-consciente">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=minas-consciente">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu pesquisa" href="javascript:void(0)">Pesquisa</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=pesquisa">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=pesquisa">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=pesquisa">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=pesquisa">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu previdencia" href="javascript:void(0)">Previdência</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=previdencia">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=previdencia">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=previdencia">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=previdencia">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu publicidade" href="javascript:void(0)">Publicidade</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=publicidade">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=publicidade">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=publicidade">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=publicidade">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu recupera-minas" href="javascript:void(0)">Recupera Minas</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=recupera-minas">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=recupera-minas">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=recupera-minas">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=recupera-minas">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu reforma-da-previdencia" href="javascript:void(0)">Reforma da Previdência</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=reforma-da-previdencia">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=reforma-da-previdencia">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=reforma-da-previdencia">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=reforma-da-previdencia">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu saude" href="javascript:void(0)">Saúde</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=saude">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=saude">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=saude">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=saude">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu defesa-social" href="javascript:void(0)">Segurança</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=defesa-social">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=defesa-social">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=defesa-social">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=defesa-social">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu servicos" href="javascript:void(0)">Serviços</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=servicos">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=servicos">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=servicos">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=servicos">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu social" href="javascript:void(0)">Social</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=social">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=social">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=social">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=social">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu trabalho" href="javascript:void(0)">Trabalho</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=trabalho">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=trabalho">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=trabalho">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=trabalho">Vídeos</a></li>
# </ul>
# </li>
# <li class="tema col-md-12 / menu">
# <a class="menu turismo" href="javascript:void(0)">Turismo</a>
# <ul class="submenu / no-bullets">
# <li><a href="/noticias?tema=turismo">Notícias</a></li>
# <li><a href="/multimidia/galerias?tema=turismo">Fotos</a></li>
# <li><a href="/multimidia/audios?tema=turismo">Áudios</a></li>
# <li><a href="/multimidia/videos?tema=turismo">Vídeos</a></li>
# </ul>
# </li>
# </ul>
# </section>
# <section class="col-md-3">
# <h1>Governador</h1>
# <ul class="no-bullets">
# <li><a href="/governador">Inicial</a></li>
# <li><a href="/governador#agenda">Agenda oficial</a></li>
# <!--<li><a href="/governador/pronunciamentos">Pronunciamentos</a></li>-->
# <!--<li><a href="/governador/biografia">Biografia</a></li>-->
# <li><a href="/multimidia/audios?governador=true">Áudio</a></li>
# <li><a href="/multimidia/videos?governador=true">Vídeo</a></li>
# <li><a href="/multimidia/galerias?governador=true">Fotos</a></li>
# </ul>
# </section>
# <section class="col-md-3">
# <h1>Regiões</h1>
# <ul class="no-bullets row">
# <li class="col-md-12"><a href="/noticias?territorio=campo-das-vertentes">Campo das Vertentes</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=central">Central</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=oeste">Centro-Oeste</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=alto-jequitinhonha">Jequitinhonha</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=metropolitano">Metropolitana de Belo Horizonte</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=noroeste">Noroeste de Minas</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=norte">Norte de Minas</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=vale-do-rio-doce">Rio Doce</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=sul">Sul e Sudoeste</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=triangulo-norte">Triângulo Mineiro e Alto Paranaíba</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=vale-do-aco">Vale do Aço</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=mucuri">Vale do Mucuri</a></li>
# <li class="col-md-12"><a href="/noticias?territorio=mata">Zona da Mata</a></li>
# </ul>
# </section>
# <section class="col-md-3">
# <ul class="no-bullets uppercase">
# <li><a class="text-title block margin-bottom-1" href="https://www.agenciaminas.mg.gov.br/multimidia/galerias">Multimídia</a></li>
#
# <a class="text-title block margin-bottom-1" href="https://www.agenciaminas.mg.gov.br/eventos">Programe-se</a>
#
# <a class="text-title block margin-bottom-1" href="/sala-de-imprensa">Sala de Imprensa</a>
#
# <a class="text-title block margin-bottom-1" href="/sites-do-governo">Sites do Governo</a>
#
# <a class="text-title block margin-bottom-1" href="https://www.mg.gov.br/" target="_blank">Serviços</a>
#
# <a class="text-title block margin-bottom-1" href="/contato">contato</a>
#
# </ul>
# </section>
# </div>
# </div>
# </div>
# <div class="footer-2 / padding-xs-y-2 padding-sm-y-5">
# <div class="container">
# <div class="row">
# <section class="social-network / margin-xs-bottom-2 margin-sm-bottom-4 / overflow-hidden">
# <div class="icon-networks">
# <div class="col-xs-12 col-sm-6">
# <!-- <i class="icon-governo text-hide">Governo de Minas Gerais</i> -->
# </div>
# <div class="social-icons / col-xs-12 col-sm-6">
# <a href="https://www.facebook.com/governomg" onclick="ga('send', 'event','Social','Facebook');" target="_blank" title="Facebook"><span class="text-hide">Facebook</span><i class="icon-facebook"> </i></a>
# <a href="https://twitter.com/governomg" onclick="ga('send', 'event','Social','Twitter');" target="_blank" title="Twitter"><span class="text-hide">Twitter</span><i class="icon-twitter"> </i></a>
# <a href="https://www.youtube.com/user/governodeminasgerais" onclick="ga('send', 'event','Social','Youtube');" target="_blank" title="Youtube"><span class="text-hide">Youtube</span><i class="icon-youtube"> </i></a>
# <a href="https://instagram.com/governomg/" onclick="ga('send', 'event','Social','Instagram');" target="_blank" title="Instagram"><span class="text-hide">Instagram</span><i class="icon-instagram"> </i></a>
# <a href="/feed" onclick="ga('send', 'event','Social','RSS');" target="_blank" title="Feed RSS"><span class="text-hide">Feed de notícias</span><i class="icon-feed2"> </i></a>
# </div>
# </div>
# </section>
# <hr class="margin-xs-bottom-3 margin-xs-top-3 / visible-xs"/>
# <section class="newsletter / col-sm-5 col-md-4 / margin-xs-bottom-2">
# <div id="form-newsletter-container">
# <p class="margin-bottom-2 text-title"><strong>Receba notícias por e-mail</strong></p>
# <!--<form id="form-newsletter" class="new_newsletter" action="/newsletter" accept-charset="UTF-8" data-remote="true" method="post"><input name="utf8" type="hidden" value="&#x2713;" /> -->
# <!--<input placeholder="Nome" required="required" type="text" name="newsletter[name]" id="newsletter_name" /> -->
# <!--<input placeholder="E-mail" required="required" type="email" name="newsletter[email]" id="newsletter_email" /> -->
# <!--<input type="submit" name="commit" value="Enviar" onclick="ga(&#39;send&#39;, &#39;event&#39;, &#39;Newsletter&#39;, &#39;Rodape&#39;);" class="margin-top-1 btn btn-secondary" id="btn-submit-newsletter" data-loading-text="Aguarde..." /> -->
# <a href="https://forms.gle/3pPi8oZuQvi4DrZS7" onclick="ga('send', 'event','Social','Cadastre-se');" target="_blank" title="CADASTRE-SE"><i class="btn btn-secondary"> CADASTRE-SE</i></a>
#  </div>
# <div class="success" id="success-message-newsletter" style="display:none;">
# <div class="success-msg">
# <i class="material-icons color-1 check"></i>
# <p>Aguarde. Em breve, retornaremos seu contato.</p>
# <br/>
# <br/>
# <p>Obrigado.</p>
# </div>
# </div>
# </section>
# <div class="col-sm-6 col-md-5 / col-sm-offset-1 col-md-offset-2">
# <hr class="margin-xs-bottom-3 margin-xs-top-3 / visible-xs / row"/>
# <section class="general-info / clear">
# <p><strong>SECOM – Secretaria de Estado de Comunicação Social</strong></p>
# <p><strong>Cidade Administrativa Presidente Tancredo Neves</strong></p>
# <p class="margin-top-2 margin-bottom-2">
# <small>
#         SECOM – Secretaria de Estado de Comunicação Social <br>
# 				Cidade Administrativa Presidente Tancredo Neves<br>
# 				Rodovia Papa João Paulo II, 3777<br>
# 				Prédio Tiradentes, 3º andar<br/>
# 				Bairro Serra Verde - Belo Horizonte (MG)<br/>
# 				CEP: 31630-903<br/>
# <a href="http://www.agenciaminas.mg.gov.br/contato"><small>Fale conosco</small></a>
# <!-- Contato: Fale conosco (http://www.agenciaminas.mg.gov.br/contato)<br /> -->
# </br></br></br></small>
# </p>
# <p><a href="/aspectos-legais"><small>Aspectos Legais e Responsabilidades</small></a></p>
# <p><a href="/politicas-de-privacidade"><small>Política de Privacidade</small></a></p>
# </section>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </body>
# </html>

# %%
print(soup.get_text(separator="\n").strip())
# Out:
# Agência Minas Gerais | Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Agência Minas Gerais
#
#
#
#
#
#
#
#
# Abrir e fechar menu
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonte
#
#
# A
#
#
# A
#
#
#
#
# contraste
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# buscar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonte
#
#
# A
#
#
# A
#
#
# contraste
#
#
#
#
#
#
#
#
# Agência Minas Gerais
#
#
#
#
#
#
#
#
#
#
# notícias
#
#
#
#
# Últimas Notícias
#
#
# Arquivo: notícias de 2005-2015
#
#
# Arquivo: notícias de 2015-2018
#
#
#
#
#
#
# multimídia
#
#
#
#
# Áudios
#
#
# Vídeos
#
#
# Fotos
#
#
#
#
#
#
# programe-se
#
#
#
#
# governador
#
#
#
#
# Inicial
#
#
# Agenda oficial
#
#
# Áudios
#
#
# Vídeos
#
#
# Fotos
#
#
#
#
#
#
# Sala de Imprensa
#
#
# Sites do Governo
#
#
# Serviços
#
#
# contato
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# buscar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Governo
#
#
# Esportes
#
#
# Educação
#
#
# Governador
#
#
#
#
#
#
#
#
# download
#
#
# 
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sáb 11 abril 2026
#
#
#
#
# 18:20
#
#
#
#
# atualizado em Sáb 11 abril 2026 18:20
#
#
#
#
# Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar
#
#
# Novo espaço amplia oportunidades para prática esportiva e atividades pedagógicas na rede municipal
#
#
#
#
#
#
#
#
#
#
#
#
# Karoline Barreto / Imprensa MG
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# download da imagem
#
#
# 
#
#
#
#
#
#
#
#
#
#
#
#
# ícone de compartilhamento
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Relacionadas
#
#
#
#
#
#
#
#
#
#
# 
#
#
#
#
#
#
# Galeria
#
#
#
#
# Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 
#
#
#
#
#
#
# Notícia
#
#
#
#
# Governo de Minas transfere capital para Poços de Caldas, anuncia novo Colégio Tiradentes e R$ 7,5 milhões para armamento da Polícia Civil
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# O governador Mateus Simões inaugurou, nessa sexta-feira (10/4), a quadra poliesportiva Rita Aparecida Carvalho Giaretta, na Escola Municipal Floriza Maniassi Trevisan, em Andradas, no Sul de Minas.
#
#
#
# A nova estrutura foi viabilizada por meio do Programa de Fortalecimento das Escolas Municipais, da
# Secretaria de Estado de Educação de Minas Gerais (SEE/MG)
# , e representa um importante avanço para a unidade, oferecendo um espaço adequado para a prática de esportes, atividades pedagógicas e integração entre os estudantes.
#
#
#
# “Com a entrega de uma das quadras no nosso programa com mais uma escola parceira, neste programa de fortalecimento das escolas municipais com verbas estaduais, percebemos como isso vai mudar a vida das crianças que estão aqui”, disse o governador Mateus Simões.
#
#
#
# A construção da quadra foi realizada por meio de um convênio, com R$ 572,8 mil de recursos do
# Governo de Minas
#  e contrapartida de R$ 94 mil da Prefeitura de Andradas.
#
#
#
# Localizada no bairro do Horto, a Escola Municipal Floriza Maniassi Trevisan atende estudantes dos anos iniciais do ensino fundamental, de manhã e à tarde. A nova estrutura contempla uma demanda antiga da comunidade, que há anos convivia com uma quadra em condições precárias, sem condições de uso.
#
#
#
# O novo espaço foi planejado para oferecer mais segurança, qualidade e ampliar o acesso às atividades esportivas e de convivência.
#
#
#
# Ao inaugurar a obra, Simões aproveitou para ressaltar outro projeto educacional, com a ampliação da rede de Colégios Tiradentes, da
# Polícia Militar de Minas Gerais (PMMG)
# , que vem sendo realizado no estado, e que terá uma nova unidade na região.
#
#
#
# “Logo aqui do lado, em Poços de Caldas, nós vamos inaugurar um Colégio Tiradentes, a partir do ano que vem, uma escola que se converte ao modelo militar, mais uma dentre as 30 que nós estamos anunciando no estado”, destacou o governador de Minas Gerais.
#
#
#
#
# Programa de fortalecimento
#
#
#
# O município de Andradas recebeu R$ 1,3 milhão em investimentos por meio do Programa de Fortalecimento das Escolas Municipais, sendo R$ 572,8 mil para a construção da quadra, R$ 100 mil para aquisição de mobiliários e equipamentos escolares, e R$ 675,6 mil para aquisição de um veículo de transporte escolar.
#
#
#
# Idealizado pela
# Secretaria de Estado de Governo (Segov-MG)
#  e pela SEE/MG, o programa tem como objetivo principal promover a qualidade da educação básica e reduzir as desigualdades educacionais em Minas Gerais.
#
#
#
# A iniciativa destina recursos de acordo com as necessidades de cada município, por meio de convênios firmados com as prefeituras. Os investimentos contemplam a aquisição de veículos escolares, mobiliário e equipamentos, além da construção, reforma e ampliação de escolas e quadras poliesportivas.
#
#
#
# Desde 2021, o programa já firmou mais de 2 mil convênios com 820 municípios mineiros, totalizando um investimento de R$ 1,7 bilhão.
#
#
#
# Entre os destaques, estão mais de 850 convênios para aquisição de veículos escolares, somando R$ 1 bilhão, mais de 860 convênios para mobiliário e equipamentos permanentes, no valor de R$ 287 milhões, e mais de 360 convênios destinados à construção e reforma de escolas municipais, totalizando R$ 377 milhões.
#
#
#
# A inauguração da quadra poliesportiva em Andradas reforça o compromisso do Governo de Minas com a educação pública, por meio de investimentos contínuos que impactam diretamente o cotidiano das escolas e contribuem para ambientes mais adequados ao ensino e à aprendizagem.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# outras notícias
#
#
#
#
#
#
#
#
#
#
# Relacionadas
#
#
#
#
#
#
#
#
# Galeria
#
#
#
#
# Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar
#
#
#
#
#
#
#
#
#
#
# Notícia
#
#
#
#
# Governo de Minas transfere capital para Poços de Caldas, anuncia novo Colégio Tiradentes e R$ 7,5 milhões para armamento da Polícia Civil
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Últimas
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Diamantina é a 6ª cidade a receber a Praça de Serviços - Governo Presente com atendimentos gratuitos à população; veja datas
#
#
# Ter 14 abril
#
#
# Projeto reúne emissão de documentos, serviços de saúde, apoio ao produtor...
#
#
#
#
# ler mais
#
#
#
#
#
#
#
#
#
#
#
#
# Governo de Minas vistoria obras da nova sede do Corpo de Bombeiros em Diamantina
#
#
# Seg 13 abril
#
#
# Com investimento de R$ 8,1 milhões, projeto contempla importantes estruturas...
#
#
#
#
# ler mais
#
#
#
#
#
#
#
#
#
#
#
#
# EMTI impulsiona protagonismo estudantil em projeto de combate à dengue em Patrocínio
#
#
# Seg 13 abril
#
#
#  Iniciativa “Minas Unidas contra o Aedes” mobiliza comunidade escolar e...
#
#
#
#
# ler mais
#
#
#
#
#
#
#
#
#
#
#
#
# Estudantes mineiros já podem solicitar isenção da taxa de inscrição do Enem 2026
#
#
# Seg 13 abril
#
#
# Estudantes da rede pública de Minas Gerais devem fazer o pedido pela Página...
#
#
#
#
# ler mais
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Temas
#
#
#
#
#
#
# Acordo do Rio Doce
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Agropecuária
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Bate-Papo com o Governador
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Brumadinho
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Ciência e Tecnologia
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Coronavírus
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Cultura
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Defesa Civil
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Desenvolvimento Econômico
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Dia da Mulher
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Direitos Humanos
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Educação
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Ensino Superior
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Esportes
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Fazenda
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Gestão
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Governador
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Governo
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Infraestrutura
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Meio Ambiente
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Minas Consciente
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Pesquisa
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Previdência
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Publicidade
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Recupera Minas
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Reforma da Previdência
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Saúde
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Segurança
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Serviços
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Social
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Trabalho
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
# Turismo
#
#
#
#
# Notícias
#
#
# Fotos
#
#
# Áudios
#
#
# Vídeos
#
#
#
#
#
#
#
#
#
#
#
#
# Governador
#
#
#
#
# Inicial
#
#
# Agenda oficial
#
#
#
#
#
#
# Áudio
#
#
# Vídeo
#
#
# Fotos
#
#
#
#
#
#
#
#
# Regiões
#
#
#
#
# Campo das Vertentes
#
#
# Central
#
#
# Centro-Oeste
#
#
# Jequitinhonha
#
#
# Metropolitana de Belo Horizonte
#
#
# Noroeste de Minas
#
#
# Norte de Minas
#
#
# Rio Doce
#
#
# Sul e Sudoeste
#
#
# Triângulo Mineiro e Alto Paranaíba
#
#
# Vale do Aço
#
#
# Vale do Mucuri
#
#
# Zona da Mata
#
#
#
#
#
#
#
#
#
#
# Multimídia
#
#
#
#
# Programe-se
#
#
#
#
# Sala de Imprensa
#
#
#
#
# Sites do Governo
#
#
#
#
# Serviços
#
#
#
#
# contato
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Facebook
#
#
#
# Twitter
#
#
#
# Youtube
#
#
#
# Instagram
#
#
#
# Feed de notícias
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Receba notícias por e-mail
#
#
#
#
#
#
#
#
#
#
#  CADASTRE-SE
#
#
#
#
#
#
#
#
#
# 
#
#
# Aguarde. Em breve, retornaremos seu contato.
#
#
#
#
#
#
# Obrigado.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SECOM – Secretaria de Estado de Comunicação Social
#
#
# Cidade Administrativa Presidente Tancredo Neves
#
#
#
#
#
#         SECOM – Secretaria de Estado de Comunicação Social
#
# 				Cidade Administrativa Presidente Tancredo Neves
#
# 				Rodovia Papa João Paulo II, 3777
#
# 				Prédio Tiradentes, 3º andar
#
# 				Bairro Serra Verde - Belo Horizonte (MG)
#
# 				CEP: 31630-903
#
#
# Fale conosco
#
#
#
#
#
#
#
#
# Aspectos Legais e Responsabilidades
#
#
# Política de Privacidade

# %% [markdown]
# A página de cada notícia contém `<meta>` tags com informações estruturadas:
#
# ```html
# <meta property="og:title" content="Título da notícia" />
# <meta name="description" property="og:description" content="Resumo..." />
# <meta property="og:image" content="https://.../imagem.jpg" />
# <meta property="article:published_time" content="2026-03-30T15:10:00-03:00" />
# ```
#
# Além disso, os **temas** ficam em botões `btn-tema`.

# %%
# Extraindo o título
title = soup.find("meta", property="og:title")["content"]

# Extraindo a descrição
description = soup.find("meta", attrs={"name": "description"})["content"]

# Extraindo a data de publicação
time_tag = soup.find("time", datetime=True)
date_str = time_tag["datetime"] if time_tag else None

# Extraindo os temas (botões btn-tema), sem duplicatas
temas = list(dict.fromkeys(
    a.get_text(strip=True)
    for a in soup.find_all("a", class_=lambda c: c and "btn-tema" in c)
))

# Extraindo a imagem
img = soup.find("meta", property="og:image")["content"]

# Extraindo o texto completo da notícia (<article class="clear">)
# Limpeza do texto: pegar só a partir do título/parágrafo real
article = soup.find("article", class_="clear")
if article:
    # Remove tags de script/style que possam estar dentro
    for tag in article.find_all(["script", "style", "figure"]):
        tag.decompose()
    texto = article.get_text(separator="\n").strip()

print("Título:", title)
print("Descrição:", description)
print("Temas:", temas)
print("Data:", date_str)
print("Imagem:", img)
print("Texto (primeiras 200 chars):", texto[:200])
# Out:
# Título: Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar
# Descrição: O governador Mateus Simões inaugurou, nessa sexta-feira (10/4), a quadra poliesportiva Rita Aparecida Carvalho Giaretta, na Escola Municipal...
# Temas: ['Governo', 'Esportes', 'Educação', 'Governador']
# Data: 2026-04-11 18:20:00 -0300
# Imagem: https://www.agenciaminas.mg.gov.br/system/news/images/000/129/656/original/NTF_3196.JPG?1775942454
# Texto (primeiras 200 chars): Sáb 11 abril 2026
#
#
#
#
# 18:20
#
#
#
#
# atualizado em Sáb 11 abril 2026 18:20
#
#
#
#
# Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar
#
#
# Novo espaço amplia oportunidad

# %%
informacoes = {
    "url": full_url,
    "titulo": title,
    "descricao": description,
    "temas": temas,
    "imagem": img,
    "data": date_str,
    "texto": texto,
}

informacoes
# Out:
# {'url': 'https://www.agenciaminas.mg.gov.br/noticia/governo-de-minas-inaugura-quadra-poliesportiva-em-andradas-e-fortalece-infraestrutura-escolar',
#  'titulo': 'Governo de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar',
#  'descricao': 'O governador Mateus Simões inaugurou, nessa sexta-feira (10/4), a quadra poliesportiva Rita Aparecida Carvalho Giaretta, na Escola Municipal...',
#  'temas': ['Governo', 'Esportes', 'Educação', 'Governador'],
#  'imagem': 'https://www.agenciaminas.mg.gov.br/system/news/images/000/129/656/original/NTF_3196.JPG?1775942454',
#  'data': '2026-04-11 18:20:00 -0300',
#  'texto': 'Sáb 11 abril 2026\n\n\n\n\n18:20\n\n\n\n\natualizado em Sáb 11 abril 2026 18:20\n\n\n\n\nGoverno de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar\n\n\nNovo espaço amplia oportunidades para prática esportiva e atividades pedagógicas na rede municipal\n\n\n\n\n\n\n\n\n\n\n\n\nKaroline Barreto / Imprensa MG\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ndownload da imagem\n\n\n\ue2c4\n\n\n\n\n\n\n\n\n\n\n\n\nícone de compartilhamento\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRelacionadas\n\n\n\n\n\n\n\n\n\n\n\ue412\n\n\n\n\n\n\nGaleria\n\n\n\n\nGoverno de Minas inaugura quadra poliesportiva em Andradas e fortalece infraestrutura escolar\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\ue236\n\n\n\n\n\n\nNotícia\n\n\n\n\nGoverno de Minas transfere capital para Poços de Caldas, anuncia novo Colégio Tiradentes e R$ 7,5 milhões para armamento da Polícia Civil\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nO governador Mateus Simões inaugurou, nessa sexta-feira (10/4), a quadra poliesportiva Rita Aparecida Carvalho Giaretta, na Escola Municipal Floriza Maniassi Trevisan, em Andradas, no Sul de Minas.\n\n\n\r\nA nova estrutura foi viabilizada por meio do Programa de Fortalecimento das Escolas Municipais, da \nSecretaria de Estado de Educação de Minas Gerais (SEE/MG)\n, e representa um importante avanço para a unidade, oferecendo um espaço adequado para a prática de esportes, atividades pedagógicas e integração entre os estudantes.\xa0\n\n\n\r\n“Com a entrega de uma das quadras no nosso programa com mais uma escola parceira, neste programa de fortalecimento das escolas municipais com verbas estaduais, percebemos como isso vai mudar a vida das crianças que estão aqui”, disse o governador Mateus Simões.\xa0\n\n\n\r\nA construção da quadra foi realizada por meio de um convênio, com R$ 572,8 mil de recursos do \nGoverno de Minas\n e contrapartida de R$ 94 mil da Prefeitura de Andradas.\n\n\n\r\nLocalizada no bairro do Horto, a Escola Municipal Floriza Maniassi Trevisan atende estudantes dos anos iniciais do ensino fundamental, de manhã e à tarde. A nova estrutura contempla uma demanda antiga da comunidade, que há anos convivia com uma quadra em condições precárias, sem condições de uso.\n\n\n\r\nO novo espaço foi planejado para oferecer mais segurança, qualidade e ampliar o acesso às atividades esportivas e de convivência.\xa0\n\n\n\r\nAo inaugurar a obra, Simões aproveitou para ressaltar outro projeto educacional, com a ampliação da rede de Colégios Tiradentes, da \nPolícia Militar de Minas Gerais (PMMG)\n, que vem sendo realizado no estado, e que terá uma nova unidade na região.\n\n\n\r\n“Logo aqui do lado, em Poços de Caldas, nós vamos inaugurar um Colégio Tiradentes, a partir do ano que vem, uma escola que se converte ao modelo militar, mais uma dentre as 30 que nós estamos anunciando no estado”, destacou o governador de Minas Gerais.\n\n\n\n\nPrograma de fortalecimento\xa0\n\n\n\r\nO município de Andradas recebeu R$ 1,3 milhão em investimentos por meio do Programa de Fortalecimento das Escolas Municipais, sendo R$ 572,8 mil para a construção da quadra, R$ 100 mil para aquisição de mobiliários e equipamentos escolares, e R$ 675,6 mil para aquisição de um veículo de transporte escolar.\xa0\n\n\n\r\nIdealizado pela \nSecretaria de Estado de Governo (Segov-MG)\n e pela SEE/MG, o programa tem como objetivo principal promover a qualidade da educação básica e reduzir as desigualdades educacionais em Minas Gerais.\n\n\n\r\nA iniciativa destina recursos de acordo com as necessidades de cada município, por meio de convênios firmados com as prefeituras. Os investimentos contemplam a aquisição de veículos escolares, mobiliário e equipamentos, além da construção, reforma e ampliação de escolas e quadras poliesportivas.\n\n\n\r\nDesde 2021, o programa já firmou mais de 2 mil convênios com 820 municípios mineiros, totalizando um investimento de R$ 1,7 bilhão.\n\n\n\r\nEntre os destaques, estão mais de 850 convênios para aquisição de veícu ...

# %% [markdown]
# ## PERDEU!!!
#
# ![image.png](attachment:ef4abcbb-c9d2-4108-aa2d-b586b85a975a.png)
#
# Agora vamos ~~roubar~~ extrair o máximo de coisas que conseguirmos sem deixar (muitas) evidências.

# %%
import time
import random

# %%
response_pg1 = requests.get(
    "https://www.agenciaminas.mg.gov.br/noticias?page=1&tema=esportes",
    headers=headers
)
soup_pg1 = BeautifulSoup(response_pg1.text, "html.parser")

paginacao = soup_pg1.find("div", class_="pagination")
ultima_pagina = max(
    int(a.get_text()) for a in paginacao.find_all("a")
    if a.get_text().strip().isdigit()
)
print(f"Total de páginas encontradas: {ultima_pagina}")
# Out:
# Total de páginas encontradas: 33

# %%
numero_paginas = 33

links_noticias = []

for p in range(1, numero_paginas + 1):
    url = f"https://www.agenciaminas.mg.gov.br/noticias?page={p}&tema=esportes"
    response = requests.get(url, headers=headers)

    print(p, response)

    soup_p = BeautifulSoup(response.text, "html.parser")
    bloco = soup_p.find("main", id="blocknews")

    if bloco:
        novos_links = list(dict.fromkeys(
            BASE + a["href"] for a in bloco.find_all("a", href=True)
            if a["href"].startswith("/noticia/")
        ))
        links_noticias += novos_links

    tempo_espera = random.uniform(0.3, 0.8)
    time.sleep(tempo_espera)

print(f"\nTotal de links coletados: {len(links_noticias)}")
# Out:
# 1 <Response [200]>
# 2 <Response [200]>
# 3 <Response [200]>
# 4 <Response [200]>
# 5 <Response [200]>
# 6 <Response [200]>
# 7 <Response [200]>
# 8 <Response [200]>
# 9 <Response [200]>
# 10 <Response [200]>
# 11 <Response [200]>
# 12 <Response [200]>
# 13 <Response [200]>
# 14 <Response [200]>
# 15 <Response [200]>
# 16 <Response [200]>
# 17 <Response [200]>
# 18 <Response [200]>
# 19 <Response [200]>
# 20 <Response [200]>
# 21 <Response [200]>
# 22 <Response [200]>
# 23 <Response [200]>
# 24 <Response [200]>
# 25 <Response [200]>
# 26 <Response [200]>
# 27 <Response [200]>
# 28 <Response [200]>
# 29 <Response [200]>
# 30 <Response [200]>
# 31 <Response [200]>
# 32 <Response [200]>
# 33 <Response [200]>
#
# Total de links coletados: 323

# %%
len(links_noticias)
# Out:
# 323

# %%
import json
import pathlib

data_dir = pathlib.Path("data_minas")
data_dir.mkdir(exist_ok=True)

for i, full_url in enumerate(links_noticias):
    response = requests.get(full_url, headers=headers)
    soup_n = BeautifulSoup(response.text, "html.parser")

    title = soup_n.find("meta", property="og:title")
    title = title["content"] if title else None

    description = soup_n.find("meta", attrs={"name": "description"})
    description = description["content"] if description else None

    date = soup_n.find("meta", property="article:published_time")
    date = date["content"] if date else None

    temas = list(dict.fromkeys(
        a.get_text(strip=True)
        for a in soup_n.find_all("a", class_=lambda c: c and "btn-tema" in c)
    ))

    img = soup_n.find("meta", property="og:image")
    imagem = img["content"] if img else None

    texto_div = soup_n.find("div", id="content")
    texto = texto_div.get_text(separator="\n").strip() if texto_div else ""

    informacoes = {
        "url": full_url,
        "titulo": title,
        "descricao": description,
        "temas": temas,
        "imagem": imagem, # Changed from 'img' to 'imagem'
        "data": date,     # Changed from 'date_str' to 'date'
        "texto": texto,
    }

    file_path = data_dir / f"noticia_{i}.json"
    with file_path.open("w", encoding="utf-8") as f:
        json.dump(informacoes, f, ensure_ascii=False, indent=4)

    print(f"[{i+1}/{len(links_noticias)}] Salvo: {file_path.name}")

    tempo_espera = random.uniform(0.2, 0.6)
    time.sleep(tempo_espera)
# Out:
# [1/323] Salvo: noticia_0.json
# [2/323] Salvo: noticia_1.json
# [3/323] Salvo: noticia_2.json
# [4/323] Salvo: noticia_3.json
# [5/323] Salvo: noticia_4.json
# [6/323] Salvo: noticia_5.json
# [7/323] Salvo: noticia_6.json
# [8/323] Salvo: noticia_7.json
# [9/323] Salvo: noticia_8.json
# [10/323] Salvo: noticia_9.json
# [11/323] Salvo: noticia_10.json
# [12/323] Salvo: noticia_11.json
# [13/323] Salvo: noticia_12.json
# [14/323] Salvo: noticia_13.json
# [15/323] Salvo: noticia_14.json
# [16/323] Salvo: noticia_15.json
# [17/323] Salvo: noticia_16.json
# [18/323] Salvo: noticia_17.json
# [19/323] Salvo: noticia_18.json
# [20/323] Salvo: noticia_19.json
# [21/323] Salvo: noticia_20.json
# [22/323] Salvo: noticia_21.json
# [23/323] Salvo: noticia_22.json
# [24/323] Salvo: noticia_23.json
# [25/323] Salvo: noticia_24.json
# [26/323] Salvo: noticia_25.json
# [27/323] Salvo: noticia_26.json
# [28/323] Salvo: noticia_27.json
# [29/323] Salvo: noticia_28.json
# [30/323] Salvo: noticia_29.json
# [31/323] Salvo: noticia_30.json
# [32/323] Salvo: noticia_31.json
# [33/323] Salvo: noticia_32.json
# [34/323] Salvo: noticia_33.json
# [35/323] Salvo: noticia_34.json
# [36/323] Salvo: noticia_35.json
# [37/323] Salvo: noticia_36.json
# [38/323] Salvo: noticia_37.json
# [39/323] Salvo: noticia_38.json
# [40/323] Salvo: noticia_39.json
# [41/323] Salvo: noticia_40.json
# [42/323] Salvo: noticia_41.json
# [43/323] Salvo: noticia_42.json
# [44/323] Salvo: noticia_43.json
# [45/323] Salvo: noticia_44.json
# [46/323] Salvo: noticia_45.json
# [47/323] Salvo: noticia_46.json
# [48/323] Salvo: noticia_47.json
# [49/323] Salvo: noticia_48.json
# [50/323] Salvo: noticia_49.json
# [51/323] Salvo: noticia_50.json
# [52/323] Salvo: noticia_51.json
# [53/323] Salvo: noticia_52.json
# [54/323] Salvo: noticia_53.json
# [55/323] Salvo: noticia_54.json
# [56/323] Salvo: noticia_55.json
# [57/323] Salvo: noticia_56.json
# [58/323] Salvo: noticia_57.json
# [59/323] Salvo: noticia_58.json
# [60/323] Salvo: noticia_59.json
# [61/323] Salvo: noticia_60.json
# [62/323] Salvo: noticia_61.json
# [63/323] Salvo: noticia_62.json
# [64/323] Salvo: noticia_63.json
# [65/323] Salvo: noticia_64.json
# [66/323] Salvo: noticia_65.json
# [67/323] Salvo: noticia_66.json
# [68/323] Salvo: noticia_67.json
# [69/323] Salvo: noticia_68.json
# [70/323] Salvo: noticia_69.json
# [71/323] Salvo: noticia_70.json
# [72/323] Salvo: noticia_71.json
# [73/323] Salvo: noticia_72.json
# [74/323] Salvo: noticia_73.json
# [75/323] Salvo: noticia_74.json
# [76/323] Salvo: noticia_75.json
# [77/323] Salvo: noticia_76.json
# [78/323] Salvo: noticia_77.json
# [79/323] Salvo: noticia_78.json
# [80/323] Salvo: noticia_79.json
# [81/323] Salvo: noticia_80.json
# [82/323] Salvo: noticia_81.json
# [83/323] Salvo: noticia_82.json
# [84/323] Salvo: noticia_83.json
# [85/323] Salvo: noticia_84.json
# [86/323] Salvo: noticia_85.json
# [87/323] Salvo: noticia_86.json
# [88/323] Salvo: noticia_87.json
# [89/323] Salvo: noticia_88.json
# [90/323] Salvo: noticia_89.json
# [91/323] Salvo: noticia_90.json
# [92/323] Salvo: noticia_91.json
# [93/323] Salvo: noticia_92.json
# [94/323] Salvo: noticia_93.json
# [95/323] Salvo: noticia_94.json
# [96/323] Salvo: noticia_95.json
# [97/323] Salvo: noticia_96.json
# [98/323] Salvo: noticia_97.json
# [99/323] Salvo: noticia_98.json
# [100/323] Salvo: noticia_99.json
# [101/323] Salvo: noticia_100.json
# [102/323] Salvo: noticia_101.json
# [103/323] Salvo: noticia_102.json
# [104/323] Salvo: noticia_103.json
# [105/323] Salvo: noticia_104.json
# [106/323] Salvo: noticia_105.json
# [107/323] Salvo: noticia_106.json
# [108/323] Salvo: noticia_107.json
# [109/323] Salvo: noticia_108.json
# [110/323] Salvo: noticia_109.json
# [111/323] Salvo: noticia_110.json
# [112/323] Salvo: noticia_111.json
# [113/323] Salvo: noticia_112.json
# [114/323] Salvo: noticia_113.json
# [115/323] Salvo: noticia_114.json
# [116/323] Salvo: noticia_115.json
# [117/323] Salvo: noticia_116.json
# [118/323] Salvo: noticia_117.json
# [119/323] Salvo: noticia_118.json
# [120/323] Salvo: noticia_119.json
# [121/323] Salvo: noticia_120.json
# [122/323] Salvo: noticia_121.json
# [123/323] Salvo: noticia_122.json
# [124/323] Salvo: noticia_123.json
# [125/323] Salvo: noticia_124.json
# [126/323] Salvo: noticia_125.json
# [127/323] Salvo: noticia_126.json
# [128/323] Salvo: noticia_127.json
# [129/323] Salvo: noticia_128.json
# [130/323] Salvo: noticia_129.json
# [131/323] Salvo: noticia_130.json
# [132/323] Salvo: noticia_131.json
# [133/323] Salvo: noticia_132.json
# [134/323] Salvo: noticia_133.json
# [135/323] Salvo: noticia_134.json
# [136/323] Salvo: noticia_135.json
# [137/323] Salvo: noticia_136.json
# [138/323] Salvo: noticia_137.json
# [139/323] Salvo: noticia_138.json
# [140/323] Salvo: noticia_139.json
# [141/323] Salvo: noticia_140.json
# [142/323] Salvo: noticia_141.json
# [143/323] Salvo: noticia_142.json
# [144/323] Salvo: noticia_143.json
# [145/323] Salvo: noticia_144.json
# [146/323] Salvo: noticia_145.json
# [147/323] Salvo: noticia_146.json
# [148/323] Salvo: noticia_147.json
# [149/323] Salvo: noticia_148.json
# [150/323] Salvo: noticia_149.json
# [151/323] Salvo: noticia_150.json
# [152/323] Salvo: noticia_151.json
# [153/323] Salvo: noticia_152.json
# [154/323] Salvo: noticia_153.json
# [155/323] Salvo: noticia_154.json
# [156/323] Salvo: noticia_155.json
# [157/323] Salvo: noticia_156.json
# [158/323] Salvo: noticia_157.json
# [159/323] Salvo: noticia_158.json
# [160/323] Salvo: noticia_159.json
# [161/323] Salvo: noticia_160.json
# [162/323] Salvo: noticia_161.json
# [163/323] Salvo: noticia_162.json
# [164/323] Salvo: noticia_163.json
# [165/323] Salvo: noticia_164.json
# [166/323] Salvo: noticia_165.json
# [167/323] Salvo: noticia_166.json
# [168/323] Salvo: noticia_167.json
# [169/323] Salvo: noticia_168.json
# [170/323] Salvo: noticia_169.json
# [171/323] Salvo: noticia_170.json
# [172/323] Salvo: noticia_171.json
# [173/323] Salvo: noticia_172.json
# [174/323] Salvo: noticia_173.json
# [175/323] Salvo: noticia_174.json
# [176/323] Salvo: noticia_175.json
# [177/323] Salvo: noticia_176.json
# [178/323] Salvo: noticia_177.json
# [179/323] Salvo: noticia_178.json
# [180/323] Salvo: noticia_179.json
# [181/323] Salvo: noticia_180.json
# [182/323] Salvo: noticia_181.json
# [183/323] Salvo: noticia_182.json
# [184/323] Salvo: noticia_183.json
# [185/323] Salvo: noticia_184.json
# [186/323] Salvo: noticia_185.json
# [187/323] Salvo: noticia_186.json
# [188/323] Salvo: noticia_187.json
# [189/323] Salvo: noticia_188.json
# [190/323] Salvo: noticia_189.json
# [191/323] Salvo: noticia_190.json
# [192/323] Salvo: noticia_191.json
# [193/323] Salvo: noticia_192.json
# [194/323] Salvo: noticia_193.json
# [195/323] Salvo: noticia_194.json
# [196/323] Salvo: noticia_195.json
# [197/323] Salvo: noticia_196.json
# [198/323] Salvo: noticia_197.json
# [199/323] Salvo: noticia_198.json
# [200/323] Salvo: noticia_199.json
# [201/323] Salvo: noticia_200.json
# [202/323] Salvo: noticia_201.json
# [203/323] Salvo: noticia_202.json
# [204/323] Salvo: noticia_203.json
# [205/323] Salvo: noticia_204.json
# [206/323] Salvo: noticia_205.json
# [207/323] Salvo: noticia_206.json
# [208/323] Salvo: noticia_207.json
# [209/323] Salvo: noticia_208.json
# [210/323] Salvo: noticia_209.json
# [211/323] Salvo: noticia_210.json
# [212/323] Salvo: noticia_211.json
# [213/323] Salvo: noticia_212.json
# [214/323] Salvo: noticia_213.json
# [215/323] Salvo: noticia_214.json
# [216/323] Salvo: noticia_215.json
# [217/323] Salvo: noticia_216.json
# [218/323] Salvo: noticia_217.json
# [219/323] Salvo: noticia_218.json
# [220/323] Salvo: noticia_219.json
# [221/323] Salvo: noticia_220.json
# [222/323] Salvo: noticia_221.json
# [223/323] Salvo: noticia_222.json
# [224/323] Salvo: noticia_223.json
# [225/323] Salvo: noticia_224.json
# [226/323] Salvo: noticia_225.json
# [227/323] Salvo: noticia_226.json
# [228/323] Salvo: noticia_227.json
# [229/323] Salvo: noticia_228.json
# [230/323] Salvo: noticia_229.json
# [231/323] Salvo: noticia_230.json
# [232/323] Salvo: noticia_231.json
# [233/323] Salvo: noticia_232.json
# [234/323] Salvo: noticia_233.json
# [235/323] Salvo: noticia_234.json
# [236/323] Salvo: noticia_235.json
# [237/323] Salvo: noticia_236.json
# [238/323] Salvo: noticia_237.json
# [239/323] Salvo: noticia_238.json
# [240/323] Salvo: noticia_239.json
# [241/323] Salvo: noticia_240.json
# [242/323] Salvo: noticia_241.json
# [243/323] Salvo: noticia_242.json
# [244/323] Salvo: noticia_243.json
# [245/323] Salvo: noticia_244.json
# [246/323] Salvo: noticia_245.json
# [247/323] Salvo: noticia_246.json
# [248/323] Salvo: noticia_247.json
# [249/323] Salvo: noticia_248.json
# [250/323] Salvo: noticia_249.json
# [251/323] Salvo: noticia_250.json
# [252/323] Salvo: noticia_251.json
# [253/323] Salvo: noticia_252.json
# [254/323] Salvo: noticia_253.json
# [255/323] Salvo: noticia_254.json
# [256/323] Salvo: noticia_255.json
# [257/323] Salvo: noticia_256.json
# [258/323] Salvo: noticia_257.json
# [259/323] Salvo: noticia_258.json
# [260/323] Salvo: noticia_259.json
# [261/323] Salvo: noticia_260.json
# [262/323] Salvo: noticia_261.json
# [263/323] Salvo: noticia_262.json
# [264/323] Salvo: noticia_263.json
# [265/323] Salvo: noticia_264.json
# [266/323] Salvo: noticia_265.json
# [267/323] Salvo: noticia_266.json
# [268/323] Salvo: noticia_267.json
# [269/323] Salvo: noticia_268.json
# [270/323] Salvo: noticia_269.json
# [271/323] Salvo: noticia_270.json
# [272/323] Salvo: noticia_271.json
# [273/323] Salvo: noticia_272.json
# [274/323] Salvo: noticia_273.json
# [275/323] Salvo: noticia_274.json
# [276/323] Salvo: noticia_275.json
# [277/323] Salvo: noticia_276.json
# [278/323] Salvo: noticia_277.json
# [279/323] Salvo: noticia_278.json
# [280/323] Salvo: noticia_279.json
# [281/323] Salvo: noticia_280.json
# [282/323] Salvo: noticia_281.json
# [283/323] Salvo: noticia_282.json
# [284/323] Salvo: noticia_283.json
# [285/323] Salvo: noticia_284.json
# [286/323] Salvo: noticia_285.json
# [287/323] Salvo: noticia_286.json
# [288/323] Salvo: noticia_287.json
# [289/323] Salvo: noticia_288.json
# [290/323] Salvo: noticia_289.json
# [291/323] Salvo: noticia_290.json
# [292/323] Salvo: noticia_291.json
# [293/323] Salvo: noticia_292.json
# [294/323] Salvo: noticia_293.json
# [295/323] Salvo: noticia_294.json
# [296/323] Salvo: noticia_295.json
# [297/323] Salvo: noticia_296.json
# [298/323] Salvo: noticia_297.json
# [299/323] Salvo: noticia_298.json
# [300/323] Salvo: noticia_299.json
# [301/323] Salvo: noticia_300.json
# [302/323] Salvo: noticia_301.json
# [303/323] Salvo: noticia_302.json
# [304/323] Salvo: noticia_303.json
# [305/323] Salvo: noticia_304.json
# [306/323] Salvo: noticia_305.json
# [307/323] Salvo: noticia_306.json
# [308/323] Salvo: noticia_307.json
# [309/323] Salvo: noticia_308.json
# [310/323] Salvo: noticia_309.json
# [311/323] Salvo: noticia_310.json
# [312/323] Salvo: noticia_311.json
# [313/323] Salvo: noticia_312.json
# [314/323] Salvo: noticia_313.json
# [315/323] Salvo: noticia_314.json
# [316/323] Salvo: noticia_315.json
# [317/323] Salvo: noticia_316.json
# [318/323] Salvo: noticia_317.json
# [319/323] Salvo: noticia_318.json
# [320/323] Salvo: noticia_319.json
# [321/323] Salvo: noticia_320.json
# [322/323] Salvo: noticia_321.json
# [323/323] Salvo: noticia_322.json

# %% [markdown]
# ## Sequestro relâmpago

# %%
from joblib import Parallel, delayed

def parsear_credito(credito):
    if not credito or credito.strip() == "":
        return None, None
    credito = credito.replace("download da imagem", "").strip()
    if "/" in credito:
        partes = credito.split("/", 1)
        return partes[0].strip(), partes[1].strip()
    return None, credito.strip()

def processar_noticia(i, full_url):
    response = requests.get(full_url, headers=headers)
    soup_n = BeautifulSoup(response.text, "html.parser")

    # Título
    title = soup_n.find("meta", property="og:title")
    title = title["content"] if title else None

    # Descrição
    description = soup_n.find("meta", attrs={"name": "description"})
    description = description["content"] if description else None

    # Data
    time_tag = soup_n.find("time", datetime=True)
    date_str = time_tag["datetime"] if time_tag else None

    # Hora de atualização (texto visível do <time>)
    hora_atualizacao = time_tag.get_text(separator=" ", strip=True) if time_tag else ""

    # Temas
    temas = list(dict.fromkeys(
        a.get_text(strip=True)
        for a in soup_n.find_all("a", class_=lambda c: c and "btn-tema" in c)
    ))

    # Imagem
    img = soup_n.find("meta", property="og:image")
    imagem = img["content"] if img else None

    # Crédito da foto
    credito_tag = soup_n.find("div", class_=lambda c: c and "news-image-text" in str(c))
    credito_foto = credito_tag.get_text(strip=True) if credito_tag else ""

    # Texto (removendo tags de figura/ícone antes de extrair)
    article = soup_n.find("article", class_="clear")
    if article:
        for tag in article.find_all(["script", "style", "figure"]):
            tag.decompose()
        texto = article.get_text(separator="\n").strip()
    else:
        texto = ""

    # Subtítulo
    subtitulo_tag = soup_n.find("h2")
    subtitulo = subtitulo_tag.get_text(strip=True) if subtitulo_tag else ""

    # Número de notícias relacionadas linkadas na página
    relacionadas = soup_n.find_all("div", class_=lambda c: c and "news-last-description" in str(c))
    n_relacionadas = len(relacionadas)

    # Número de palavras do título
    n_palavras_titulo = len(title.split()) if title else 0

    fotografo, orgao_foto = parsear_credito(credito_foto)

    informacoes = {
        "url":              full_url,
        "titulo":           title,
        "subtitulo":        subtitulo,
        "descricao":        description,
        "temas":            temas,
        "imagem":           imagem,
        "fotografo":        fotografo,
        "orgao_foto":       orgao_foto,
        "data":             date_str,
        "hora_atualizacao": hora_atualizacao,
        "texto":            texto,
        "n_relacionadas":   n_relacionadas,
        "n_palavras_titulo":n_palavras_titulo,
    }

    file_path = data_dir / f"noticia_{i}.json"
    with file_path.open("w", encoding="utf-8") as f:
        json.dump(informacoes, f, ensure_ascii=False, indent=4)

    print(f"Arquivo salvo: {file_path.name}")
    time.sleep(random.uniform(0, 0.3))

# Executa em paralelo com threads
Parallel(n_jobs=8, prefer="threads")(
    delayed(processar_noticia)(i, link) for i, link in enumerate(links_noticias)
)
# Out:
# Arquivo salvo: noticia_1.json
# Arquivo salvo: noticia_3.json
# Arquivo salvo: noticia_5.json
# Arquivo salvo: noticia_0.json
# Arquivo salvo: noticia_4.json
# Arquivo salvo: noticia_7.json
# Arquivo salvo: noticia_6.json
# Arquivo salvo: noticia_2.json
# Arquivo salvo: noticia_8.json
# Arquivo salvo: noticia_9.json
# Arquivo salvo: noticia_10.json
# Arquivo salvo: noticia_12.json
# Arquivo salvo: noticia_14.json
# Arquivo salvo: noticia_13.json
# Arquivo salvo: noticia_15.json
# Arquivo salvo: noticia_16.json
# Arquivo salvo: noticia_17.json
# Arquivo salvo: noticia_18.json
# Arquivo salvo: noticia_19.json
# Arquivo salvo: noticia_11.json
# Arquivo salvo: noticia_20.json
# Arquivo salvo: noticia_21.json
# Arquivo salvo: noticia_23.json
# Arquivo salvo: noticia_24.json
# Arquivo salvo: noticia_22.json
# Arquivo salvo: noticia_25.json
# Arquivo salvo: noticia_26.json
# Arquivo salvo: noticia_27.json
# Arquivo salvo: noticia_28.json
# Arquivo salvo: noticia_29.json
# Arquivo salvo: noticia_30.json
# Arquivo salvo: noticia_31.json
# Arquivo salvo: noticia_32.json
# Arquivo salvo: noticia_33.json
# Arquivo salvo: noticia_34.json
# Arquivo salvo: noticia_35.json
# Arquivo salvo: noticia_36.json
# Arquivo salvo: noticia_38.json
# Arquivo salvo: noticia_39.json
# Arquivo salvo: noticia_40.json
# Arquivo salvo: noticia_37.json
# Arquivo salvo: noticia_41.json
# Arquivo salvo: noticia_42.json
# Arquivo salvo: noticia_43.json
# Arquivo salvo: noticia_44.json
# Arquivo salvo: noticia_47.json
# Arquivo salvo: noticia_48.json
# Arquivo salvo: noticia_45.json
# Arquivo salvo: noticia_46.json
# Arquivo salvo: noticia_49.json
# Arquivo salvo: noticia_50.json
# Arquivo salvo: noticia_51.json
# Arquivo salvo: noticia_53.json
# Arquivo salvo: noticia_52.json
# Arquivo salvo: noticia_54.json
# Arquivo salvo: noticia_55.json
# Arquivo salvo: noticia_56.json
# Arquivo salvo: noticia_57.json
# Arquivo salvo: noticia_59.json
# Arquivo salvo: noticia_60.json
# Arquivo salvo: noticia_61.json
# Arquivo salvo: noticia_62.json
# Arquivo salvo: noticia_58.json
# Arquivo salvo: noticia_64.json
# Arquivo salvo: noticia_63.json
# Arquivo salvo: noticia_65.json
# Arquivo salvo: noticia_66.json
# Arquivo salvo: noticia_67.json
# Arquivo salvo: noticia_69.json
# Arquivo salvo: noticia_68.json
# Arquivo salvo: noticia_71.json
# Arquivo salvo: noticia_70.json
# Arquivo salvo: noticia_72.json
# Arquivo salvo: noticia_73.json
# Arquivo salvo: noticia_74.json
# Arquivo salvo: noticia_75.json
# Arquivo salvo: noticia_77.json
# Arquivo salvo: noticia_78.json
# Arquivo salvo: noticia_79.json
# Arquivo salvo: noticia_76.json
# Arquivo salvo: noticia_80.json
# Arquivo salvo: noticia_81.json
# Arquivo salvo: noticia_82.json
# Arquivo salvo: noticia_84.json
# Arquivo salvo: noticia_83.json
# Arquivo salvo: noticia_85.json
# Arquivo salvo: noticia_86.json
# Arquivo salvo: noticia_88.json
# Arquivo salvo: noticia_89.json
# Arquivo salvo: noticia_87.json
# Arquivo salvo: noticia_90.json
# Arquivo salvo: noticia_91.json
# Arquivo salvo: noticia_92.json
# Arquivo salvo: noticia_94.json
# Arquivo salvo: noticia_95.json
# Arquivo salvo: noticia_97.json
# Arquivo salvo: noticia_93.json
# Arquivo salvo: noticia_96.json
# Arquivo salvo: noticia_98.json
# Arquivo salvo: noticia_100.json
# Arquivo salvo: noticia_101.json
# Arquivo salvo: noticia_99.json
# Arquivo salvo: noticia_102.json
# Arquivo salvo: noticia_104.json
# Arquivo salvo: noticia_105.json
# Arquivo salvo: noticia_103.json
# Arquivo salvo: noticia_106.json
# Arquivo salvo: noticia_107.json
# Arquivo salvo: noticia_108.json
# Arquivo salvo: noticia_110.json
# Arquivo salvo: noticia_109.json
# Arquivo salvo: noticia_111.json
# Arquivo salvo: noticia_112.json
# Arquivo salvo: noticia_113.json
# Arquivo salvo: noticia_114.json
# Arquivo salvo: noticia_115.json
# Arquivo salvo: noticia_116.json
# Arquivo salvo: noticia_118.json
# Arquivo salvo: noticia_117.json
# Arquivo salvo: noticia_119.json
# Arquivo salvo: noticia_120.json
# Arquivo salvo: noticia_121.json
# Arquivo salvo: noticia_122.json
# Arquivo salvo: noticia_123.json
# Arquivo salvo: noticia_124.json
# Arquivo salvo: noticia_125.json
# Arquivo salvo: noticia_126.json
# Arquivo salvo: noticia_127.json
# Arquivo salvo: noticia_129.json
# Arquivo salvo: noticia_128.json
# Arquivo salvo: noticia_131.jsonArquivo salvo: noticia_130.json
#
# Arquivo salvo: noticia_132.json
# Arquivo salvo: noticia_133.json
# Arquivo salvo: noticia_134.json
# Arquivo salvo: noticia_135.json
# Arquivo salvo: noticia_136.json
# Arquivo salvo: noticia_137.json
# Arquivo salvo: noticia_138.json
# Arquivo salvo: noticia_140.json
# Arquivo salvo: noticia_139.json
# Arquivo salvo: noticia_141.json
# Arquivo salvo: noticia_142.json
# Arquivo salvo: noticia_143.json
# Arquivo salvo: noticia_144.json
# Arquivo salvo: noticia_147.json
# Arquivo salvo: noticia_145.json
# Arquivo salvo: noticia_148.json
# Arquivo salvo: noticia_146.jsonArquivo salvo: noticia_149.json
#
# Arquivo salvo: noticia_150.json
# Arquivo salvo: noticia_151.json
# Arquivo salvo: noticia_152.json
# Arquivo salvo: noticia_154.json
# Arquivo salvo: noticia_153.json
# Arquivo salvo: noticia_155.json
# Arquivo salvo: noticia_156.json
# Arquivo salvo: noticia_159.json
# Arquivo salvo: noticia_157.json
# Arquivo salvo: noticia_158.json
# Arquivo salvo: noticia_160.json
# Arquivo salvo: noticia_161.json
# Arquivo salvo: noticia_164.json
# Arquivo salvo: noticia_162.json
# Arquivo salvo: noticia_166.json
# Arquivo salvo: noticia_165.json
# Arquivo salvo: noticia_163.json
# Arquivo salvo: noticia_168.json
# Arquivo salvo: noticia_169.json
# Arquivo salvo: noticia_170.json
# Arquivo salvo: noticia_171.json
# Arquivo salvo: noticia_167.json
# Arquivo salvo: noticia_172.json
# Arquivo salvo: noticia_173.json
# Arquivo salvo: noticia_174.json
# Arquivo salvo: noticia_175.json
# Arquivo salvo: noticia_177.json
# Arquivo salvo: noticia_176.json
# Arquivo salvo: noticia_179.json
# Arquivo salvo: noticia_178.json
# Arquivo salvo: noticia_181.jsonArquivo salvo: noticia_182.json
#
# Arquivo salvo: noticia_180.json
# Arquivo salvo: noticia_183.json
# Arquivo salvo: noticia_184.json
# Arquivo salvo: noticia_185.json
# Arquivo salvo: noticia_187.json
# Arquivo salvo: noticia_186.json
# Arquivo salvo: noticia_189.json
# Arquivo salvo: noticia_190.json
# Arquivo salvo: noticia_188.json
# Arquivo salvo: noticia_191.json
# Arquivo salvo: noticia_192.json
# Arquivo salvo: noticia_193.json
# Arquivo salvo: noticia_194.json
# Arquivo salvo: noticia_195.json
# Arquivo salvo: noticia_196.json
# Arquivo salvo: noticia_197.json
# Arquivo salvo: noticia_198.jsonArquivo salvo: noticia_199.json
#
# Arquivo salvo: noticia_200.json
# Arquivo salvo: noticia_201.json
# Arquivo salvo: noticia_203.json
# Arquivo salvo: noticia_202.json
# Arquivo salvo: noticia_205.json
# Arquivo salvo: noticia_204.json
# Arquivo salvo: noticia_206.json
# Arquivo salvo: noticia_208.jsonArquivo salvo: noticia_207.json
#
# Arquivo salvo: noticia_209.json
# Arquivo salvo: noticia_210.json
# Arquivo salvo: noticia_212.json
# Arquivo salvo: noticia_214.json
# Arquivo salvo: noticia_213.json
# Arquivo salvo: noticia_211.json
# Arquivo salvo: noticia_217.json
# Arquivo salvo: noticia_215.json
# Arquivo salvo: noticia_216.json
# Arquivo salvo: noticia_218.json
# Arquivo salvo: noticia_220.jsonArquivo salvo: noticia_219.json
#
# Arquivo salvo: noticia_221.json
# Arquivo salvo: noticia_222.json
# Arquivo salvo: noticia_223.json
# Arquivo salvo: noticia_224.json
# Arquivo salvo: noticia_225.json
# Arquivo salvo: noticia_226.json
# Arquivo salvo: noticia_227.json
# Arquivo salvo: noticia_228.jsonArquivo salvo: noticia_229.json
#
# Arquivo salvo: noticia_232.json
# Arquivo salvo: noticia_231.json
# Arquivo salvo: noticia_233.json
# Arquivo salvo: noticia_230.json
# Arquivo salvo: noticia_234.json
# Arquivo salvo: noticia_236.json
# Arquivo salvo: noticia_237.json
# Arquivo salvo: noticia_235.json
# Arquivo salvo: noticia_238.json
# Arquivo salvo: noticia_239.json
# Arquivo salvo: noticia_240.json
# Arquivo salvo: noticia_242.json
# Arquivo salvo: noticia_241.json
# Arquivo salvo: noticia_243.json
# Arquivo salvo: noticia_244.json
# Arquivo salvo: noticia_246.json
# Arquivo salvo: noticia_245.json
# Arquivo salvo: noticia_247.json
# Arquivo salvo: noticia_248.json
# Arquivo salvo: noticia_250.json
# Arquivo salvo: noticia_249.json
# Arquivo salvo: noticia_251.json
# Arquivo salvo: noticia_252.json
# Arquivo salvo: noticia_254.json
# Arquivo salvo: noticia_253.json
# Arquivo salvo: noticia_256.json
# Arquivo salvo: noticia_255.json
# Arquivo salvo: noticia_257.json
# Arquivo salvo: noticia_258.json
# Arquivo salvo: noticia_259.json
# Arquivo salvo: noticia_260.json
# Arquivo salvo: noticia_261.json
# Arquivo salvo: noticia_262.jsonArquivo salvo: noticia_263.json
#
# Arquivo salvo: noticia_265.json
# Arquivo salvo: noticia_266.json
# Arquivo salvo: noticia_264.json
# Arquivo salvo: noticia_267.json
# Arquivo salvo: noticia_268.json
# Arquivo salvo: noticia_270.json
# Arquivo salvo: noticia_269.json
# Arquivo salvo: noticia_271.json
# Arquivo salvo: noticia_273.json
# Arquivo salvo: noticia_272.json
# Arquivo salvo: noticia_275.json
# Arquivo salvo: noticia_276.json
# Arquivo salvo: noticia_274.json
# Arquivo salvo: noticia_277.json
# Arquivo salvo: noticia_278.json
# Arquivo salvo: noticia_280.json
# Arquivo salvo: noticia_279.json
# Arquivo salvo: noticia_282.json
# Arquivo salvo: noticia_281.json
# Arquivo salvo: noticia_284.jsonArquivo salvo: noticia_283.json
#
# Arquivo salvo: noticia_285.json
# Arquivo salvo: noticia_286.json
# Arquivo salvo: noticia_287.json
# Arquivo salvo: noticia_289.json
# Arquivo salvo: noticia_288.json
# Arquivo salvo: noticia_290.json
# Arquivo salvo: noticia_291.json
# Arquivo salvo: noticia_292.json
# Arquivo salvo: noticia_293.json
# Arquivo salvo: noticia_294.json
# Arquivo salvo: noticia_295.json
# Arquivo salvo: noticia_297.json
# Arquivo salvo: noticia_298.json
# Arquivo salvo: noticia_296.json
# Arquivo salvo: noticia_299.json
# Arquivo salvo: noticia_300.json
# Arquivo salvo: noticia_301.json
# Arquivo salvo: noticia_302.json
# Arquivo salvo: noticia_303.json
# Arquivo salvo: noticia_305.json
# Arquivo salvo: noticia_304.json
# Arquivo salvo: noticia_306.json
# Arquivo salvo: noticia_307.json
# Arquivo salvo: noticia_308.json
# Arquivo salvo: noticia_309.json
# Arquivo salvo: noticia_311.json
# Arquivo salvo: noticia_310.json
# Arquivo salvo: noticia_312.json
# Arquivo salvo: noticia_313.json
# Arquivo salvo: noticia_315.json
# Arquivo salvo: noticia_314.json
# Arquivo salvo: noticia_316.json
# Arquivo salvo: noticia_317.json
# Arquivo salvo: noticia_319.json
# Arquivo salvo: noticia_318.json
# Arquivo salvo: noticia_320.json
# Arquivo salvo: noticia_321.json
# Arquivo salvo: noticia_322.json
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ## Análise dos nossos espólios
#
# ![image.png](attachment:aee4be16-6db6-4249-b70e-f0202d6452e6.png)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import json
import pathlib

data_dir = pathlib.Path("data_minas")
registros = []

for json_file in data_dir.rglob("*.json"):
    try:
        with json_file.open("r", encoding="utf-8") as f:
            data = json.load(f)
    except json.JSONDecodeError:
        print(f"Skipping corrupted file: {json_file}")
        continue

    date_str = data.get("data", "")
    date = None
    if date_str:
        try:
            date = datetime.fromisoformat(date_str)
        except ValueError:
            try:
                date = datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S %z")
            except ValueError:
                try:
                    date = datetime.strptime(date_str, "%Y-%m-%d %H:%M:%S")
                except ValueError:
                    pass

    texto = data.get("texto", "")
    temas = data.get("temas", [])

    fotografo, orgao_foto = parsear_credito(data.get("credito_foto", ""))

    registros.append({
        "titulo":            data.get("titulo", ""),
        "subtitulo":         data.get("subtitulo", ""),
        "descricao":         data.get("descricao", ""),
        "temas":             temas,
        "data":              date,
        "ano_mes":           date.strftime("%Y-%m") if date else None,
        "ano":               date.year  if date else None,
        "mes":               date.month if date else None,
        "hora":              date.hour  if date else None,
        "turno":             ("Manhã" if date and date.hour < 12 else
                              "Tarde" if date and date.hour < 18 else
                              "Noite" if date else None),
        "n_temas":           len(temas),
        "tamanho_texto":     len(texto.split()),
        "n_palavras_titulo": data.get("n_palavras_titulo", 0),
        "n_relacionadas":    data.get("n_relacionadas", 0),
        "url":               data.get("url", ""),
    })

df = pd.DataFrame(registros)

print(f"Total de notícias carregadas: {len(df)}")
print(f"Com data:  {df['data'].notna().sum()}")
print(f"Com texto: {(df['tamanho_texto'] > 0).sum()}")
df.head()
# Out:
# Total de notícias carregadas: 323
# Com data:  323
# Com texto: 323
#                                               titulo  \
# 0  Governo de Minas inaugura quadra poliesportiva...
# 1  Governo de Minas vistoria obras de revitalizaç...
# 2  Estudantes da rede estadual conquistam o 1º lu...
# 3  Avanços inéditos em políticas de desenvolvimen...
# 4  Governo de Minas divulga primeiro mascote dos ...
#
#                                            subtitulo  \
# 0  Novo espaço amplia oportunidades para prática ...
# 1  Restauro da estrutura fortalece o esporte e a ...
# 2  Irmãos Sandra Thauany e Bernardo Castro, da Es...
# 3  Prestação de contas a deputados focou em reali...
# 4  Golden Retriever venceu concurso de votação po...
#
#                                            descricao  \
# 0  O governador Mateus Simões inaugurou, nessa se...
# 1  O governador de Minas Gerais, Mateus Simões, v...
# 2  O desempenho dos estudantes da rede estadual m...
# 3  O Governo de Minas avança em políticas pública...
# 4  O primeiro mascote dos Jogos Escolares de Mina...
#
#                                        temas                       data  \
# 0  [Governo, Esportes, Educação, Governador]  2026-04-11 18:20:00-03:00
# 1    [Social, Governo, Esportes, Governador]  2026-04-09 14:50:00-03:00
# 2                       [Esportes, Educação]  2025-11-14 12:55:00-03:00
# 3       [Social, Esportes, Direitos Humanos]  2024-06-26 20:05:00-03:00
# 4                       [Esportes, Educação]  2024-06-24 17:30:00-03:00
#
#    ano_mes   ano  mes  hora  turno  n_temas  tamanho_texto  n_palavras_titulo  \
# 0  2026-04  2026    4    18  Noite        4            630                 12
# 1  2026-04  2026    4    14  Tarde        4            576                 14
# 2  2025-11  2025   11    12  Tarde        2            502                 13
# 3  2024-06  2024    6    20  Noite        3            710                 14
# 4  2024-06  2024    6    17  Tarde        2            552                 12
#
#    n_relacionadas                                                url
# 0               4  https://www.agenciaminas.mg.gov.br/noticia/gov...
# 1               4  https://www.agenciaminas.mg.gov.br/noticia/gov...
# 2               4  https://www.agenciaminas.mg.gov.br/noticia/est...
# 3               4  https://www.agenciaminas.mg.gov.br/noticia/ava...
# 4               4  https://www.agenciaminas.mg.gov.br/noticia/gov...

# %%
df.to_csv("data_minas/noticias_agencia_minas.csv", index=False, encoding="utf-8-sig")
print(f"CSV salvo com {len(df)} linhas!")
# Out:
# CSV salvo com 323 linhas!

# %%
noticias_por_mes = df.dropna(subset=["ano_mes"]).groupby("ano_mes").size()

plt.figure(figsize=(14, 5))
plt.plot(noticias_por_mes.index, noticias_por_mes.values,
         marker="o", color="steelblue", linewidth=2)
plt.fill_between(noticias_por_mes.index, noticias_por_mes.values,
                 alpha=0.2, color="steelblue")
plt.xlabel("Mês")
plt.ylabel("Nº de Notícias")
plt.title("Volume de Notícias por Mês — Agência Minas Esportes")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
df_temas = df.explode("temas").dropna(subset=["temas"])
tema_counts = df_temas["temas"].value_counts().head(15)

plt.figure(figsize=(12, 6))
bars = plt.bar(tema_counts.index, tema_counts.values,
               color=plt.cm.tab20.colors[:len(tema_counts)])
plt.xlabel("Tema")
plt.ylabel("Frequência")
plt.title("Top 15 Temas Mais Frequentes — Agência Minas")
plt.xticks(rotation=45, ha="right")
for bar, val in zip(bars, tema_counts.values):
    plt.text(bar.get_x() + bar.get_width()/2,
             bar.get_height() + 0.3, str(val), ha="center", fontsize=9)
plt.tight_layout()
plt.show()
